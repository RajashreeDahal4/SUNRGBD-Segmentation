# %% [markdown]
# <a href="https://colab.research.google.com/github/RajashreeDahal4/SUNRGBD-Segmentation/blob/main/Untitled121june19_skip_multiply.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.4.1
import tensorflow
print(tensorflow.__version__)
# Out:
# Requirement already satisfied: tensorflow==2.4.1 in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.15.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.3.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.5.0)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.32.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.12.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.2.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.7.4.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (3.12.4)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.19.5)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.36.2)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (0.3.3)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (1.1.2)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.1) (2.10.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (57.0.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.31.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2.10)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.2.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (3.4.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.4.8)
# 2.4.1

# %%
# !pip3 install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py) (1.15.0)

# %%
# model.summary()

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import h5py
import cv2 as cv 
from PIL import Image, ImageDraw
import json 
import os 
import glob 
import re 
from tqdm import tqdm
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Conv2D, Reshape, Concatenate,MaxPooling2D, AveragePooling2D,Input, BatchNormalization, Activation, UpSampling2D, Concatenate, LeakyReLU,Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D,Multiply,SpatialDropout2D
from tensorflow.keras.optimizers import Adam 
#using tensorflow backend 16 so keras backend still 32bytes so no keras to be used
# from keras.layers.merge import concatenate,Concatenate
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import gc
import psutil

# %%
tf.keras.mixed_precision.experimental.set_policy('mixed_float16')
# # tf.compat.v1.disable_eager_execution()
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: Tesla T4, compute capability 7.5

# %%
category = """wall, floor, cabinet, bed, chair, sofa, table, door, window, bookshelf, picture, counter, blinds, desk, shelves, curtain, dresser
, pillow, mirror, floor mat, clothes, ceiling, books, fridge, tv, paper, towel, shower curtain, box, whiteboard, person, nightstand, toilet, sink
, lamp, bathtub, bag"""
category = category.split(r', ')
category = [i.replace('\n','') for i in category]
category_1 = ['background']
for categ in category:category_1.append(categ) 
print(category_1)
category_dict = {k:category_1.index(k) for k in category_1}
print(category_dict)
reverse_map={i:k for k,i in category_dict.items()}
color_list=['gray','red','green','#FFFF00','#8c564b','#4B8BBE','#306998','#FFE873','#FFD43B','#646464','#5a0000','#003a27','#C0C0C0','#808080','#800000','#808000','#00FF00','#00FFFF','#008080','#000080','#FF00FF','#800080','#CD5C5C','#F08080','#FA8072','#E9967A','#FFA07A','#DC143C','#FF7F50','#FFD700','#ffffe0','#bdb76b','#228b22','#B0E0E6','#4169e1','#f0ffff','#d2691e','#BC8F8F']
class_color_map={k:color_list[i] for i,k in enumerate(reverse_map.keys())}
# Out:
# ['background', 'wall', 'floor', 'cabinet', 'bed', 'chair', 'sofa', 'table', 'door', 'window', 'bookshelf', 'picture', 'counter', 'blinds', 'desk', 'shelves', 'curtain', 'dresser', 'pillow', 'mirror', 'floor mat', 'clothes', 'ceiling', 'books', 'fridge', 'tv', 'paper', 'towel', 'shower curtain', 'box', 'whiteboard', 'person', 'nightstand', 'toilet', 'sink', 'lamp', 'bathtub', 'bag']
# {'background': 0, 'wall': 1, 'floor': 2, 'cabinet': 3, 'bed': 4, 'chair': 5, 'sofa': 6, 'table': 7, 'door': 8, 'window': 9, 'bookshelf': 10, 'picture': 11, 'counter': 12, 'blinds': 13, 'desk': 14, 'shelves': 15, 'curtain': 16, 'dresser': 17, 'pillow': 18, 'mirror': 19, 'floor mat': 20, 'clothes': 21, 'ceiling': 22, 'books': 23, 'fridge': 24, 'tv': 25, 'paper': 26, 'towel': 27, 'shower curtain': 28, 'box': 29, 'whiteboard': 30, 'person': 31, 'nightstand': 32, 'toilet': 33, 'sink': 34, 'lamp': 35, 'bathtub': 36, 'bag': 37}

# %%
AUTO = tf.data.experimental.AUTOTUNE
Image_width = 640 
Image_height = 480 
no_classes = len(category_dict)
def load_data(path, split=0.2):
    images = sorted(glob.glob(os.path.join(path, "image/*")))
    print(len(images))
    masks = sorted(glob.glob(os.path.join(path, "mask2/*")))
    print(len(masks))
    total_size = 8033
    test_size = 2033
    valid_size=1000
    training_x, test_x = train_test_split(images[:8033], test_size=test_size, random_state=42)
    training_y, test_y = train_test_split(masks[:8033], test_size=test_size, random_state=42)
    train_x, valid_x = train_test_split(training_x, test_size=valid_size, random_state=42)
    train_y, valid_y = train_test_split(training_y, test_size=valid_size, random_state=42)
    return (train_x, train_y), (valid_x, valid_y),(test_x, test_y)
(train_x,train_y),(valid_x,valid_y),(test_x, test_y)=load_data('/content/drive/MyDrive/depth')
train_size=len(train_x)
valid_size=len(valid_x)

def read_image(path):
    path = path.decode()
    x = cv.imread(path, cv.IMREAD_COLOR)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_AREA)
    x = x/255.0
    x=tf.cast(x,dtype=tf.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv.imread(path, cv.IMREAD_GRAYSCALE)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_NEAREST)
  
    x = to_categorical(x,num_classes=no_classes)
    x = x[:,:,:]
    # x = np.expand_dims(x, axis=-1)
    # x=np.concatenate([x,x],axis=-1)
    x=tf.cast(x,dtype=tf.float32)
    return x
# read_mask('/content/drive/MyDrive/depth/mask100/mask1.png')
def parser(x,y):
    def _parse(x,y):
        x=read_image(x)
        y=read_mask(y)
        return x,y
    x,y = tf.numpy_function(_parse, [x,y], [tf.float32,tf.float32])
    x.set_shape([Image_height, Image_width, 3])
    y.set_shape([Image_height, Image_width, no_classes])
    return x,y
    
def tf_dataset(x, y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(parser)
    # dataset = dataset.cache()
    dataset = dataset.repeat()
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(AUTO)
    return dataset
train_dataset=tf_dataset(train_x,train_y,batch=16)
valid_dataset=tf_dataset(valid_x,valid_y,batch=16)
valid_dataset
# Out:
# 8033
# 8033
# <PrefetchDataset shapes: ((None, 480, 640, 3), (None, 480, 640, 38)), types: (tf.float32, tf.float32)>

# %%
print(test_x[:100])
# Out:
# ['/content/drive/MyDrive/depth/image/image1034.jpg', '/content/drive/MyDrive/depth/image/image1018.jpg', '/content/drive/MyDrive/depth/image/image1048.jpg', '/content/drive/MyDrive/depth/image/image1061.jpg', '/content/drive/MyDrive/depth/image/image1.jpg', '/content/drive/MyDrive/depth/image/image1021.jpg', '/content/drive/MyDrive/depth/image/image1033.jpg', '/content/drive/MyDrive/depth/image/image1057.jpg', '/content/drive/MyDrive/depth/image/image1007.jpg']

# %%
#changes 
#Added a extra convolution in the encoder part lets look if it makes improvement or not 
# def squeeze_excite_block(inputs, ratio=8):
#     init = inputs
#     channel_axis = -1
#     filters = init.shape[channel_axis]
#     se_shape = (1, 1, filters)

#     se = GlobalAveragePooling2D()(init)
#     se = Reshape(se_shape)(se)
#     se = Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
#     se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)

#     x = Multiply()([init, se])
#     return x
def encoder_conv_block(inputs,filters):
  x = Conv2D(filters, (3, 3), padding="same",kernel_initializer='he_normal')(inputs)
  x = SpatialDropout2D(0.1)(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.001)(x)
  x = Conv2D(filters, (3, 3), padding="same",kernel_initializer='he_normal')(x)
  x = SpatialDropout2D(0.1)(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.001)(x)
  return x 
def decoder_conv_block(inputs,filters,filters2):
  x = Conv2D(filters, (3, 3), padding="same",kernel_initializer='he_normal')(inputs)
  x = SpatialDropout2D(0.1)(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.001)(x)
  x = Conv2D(filters2, (3, 3), padding="same",kernel_initializer='he_normal')(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.001)(x)
  return x
def experiment2(inputs,filters):
  x = Conv2D(filters, (3, 3), padding="same",kernel_initializer='he_normal')(inputs)
  x = SpatialDropout2D(0.1)(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.001)(x)
  x = Conv2D(filters, (3, 3), padding="same",kernel_initializer='he_normal')(x)
  x = SpatialDropout2D(0.1)(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.001)(x)
  x = Conv2D(1, (1, 1), padding="same",kernel_initializer='he_normal')(x)
  x = BatchNormalization()(x)
  x = LeakyReLU(alpha=0.001)(x)
  return x 

def experiment(inputs, ratio=8):
    init = inputs
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)
    return se

def encoder(inputs):
  num_filters = [32,64,128,256,256]
  x= inputs
  skip_connections= []
  for i,filters  in enumerate(num_filters):
    x = encoder_conv_block(x,filters)
    print(x.shape)
    if i in [1,2,3,4]:
      added_layer = experiment2(x,filters)
    # #   added_layer2 =experiment2(x,filters)
    #   print(added_layer.shape)
      skip_connections.append(added_layer)
    x = MaxPooling2D((2, 2))(x)
  return x ,skip_connections

def multiply_hero(x,skip_layers,filters):
  x1= experiment2(skip_layers,filters)
  x= Multiply()([x,skip_layers])
  return x 

def decoder(x,skip_layers):
  skip_layers.reverse()
  num_filters = [32,64, 128,256,256,512]
  num_filters.reverse()
  for i in range(len(num_filters)-1):
    x = decoder_conv_block(x,num_filters[i],num_filters[i+1])
    x = UpSampling2D((2,2))(x)
    print(x.shape)
    if i in [0,1, 2,3]:
      x= Multiply()([x,skip_layers[i]])
  return x
def output_block(inputs,classes):
    #  x = Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal')(inputs)
    #  x = BatchNormalization()(x)
    #  x = LeakyReLU(alpha=0.001)(x)
     x = Conv2D(classes,(1, 1), padding="same")(inputs)
     return x
def main_model(shape):
  inputs = Input(shape)
  encoded,skip_layers= encoder(inputs)
  decoded = decoder(encoded,skip_layers)
  output = output_block(decoded,classes=38)
  model = Model(inputs,output)
  return model

model2 = main_model((480,640,3))
# Out:
# (None, 480, 640, 32)
# (None, 240, 320, 64)
# (None, 120, 160, 128)
# (None, 60, 80, 256)
# (None, 30, 40, 256)
# (None, 30, 40, 256)
# (None, 60, 80, 256)
# (None, 120, 160, 128)
# (None, 240, 320, 64)
# (None, 480, 640, 32)

# %%
config = model.get_config()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b3e0c13f48b7> in <module>()
# ----> 1 config = model.get_config()
#
# NameError: name 'model' is not defined

# %%
model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 480, 640, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 480, 640, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d (SpatialDropo (None, 480, 640, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 480, 640, 32) 128         spatial_dropout2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 480, 640, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 480, 640, 32) 9248        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 480, 640, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 480, 640, 32) 128         spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 480, 640, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 240, 320, 32) 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 240, 320, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 240, 320, 64) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 240, 320, 64) 256         spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 240, 320, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 240, 320, 64) 36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 240, 320, 64) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 240, 320, 64) 256         spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 240, 320, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 160, 64) 0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 120, 160, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_6 (SpatialDro (None, 120, 160, 128 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 120, 160, 128 512         spatial_dropout2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 120, 160, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 120, 160, 128 147584      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_7 (SpatialDro (None, 120, 160, 128 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 120, 160, 128 512         spatial_dropout2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 120, 160, 128 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 80, 128)  0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 60, 80, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10 (SpatialDr (None, 60, 80, 256)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 80, 256)  1024        spatial_dropout2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 60, 80, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 80, 256)  590080      leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_11 (SpatialDr (None, 60, 80, 256)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 80, 256)  1024        spatial_dropout2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 60, 80, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 30, 40, 256)  0           leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 30, 40, 256)  590080      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_14 (SpatialDr (None, 30, 40, 256)  0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 30, 40, 256)  1024        spatial_dropout2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 30, 40, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 30, 40, 256)  590080      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_15 (SpatialDr (None, 30, 40, 256)  0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 30, 40, 256)  1024        spatial_dropout2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 30, 40, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 30, 40, 256)  590080      leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_16 (SpatialDr (None, 30, 40, 256)  0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 15, 20, 256)  0           leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 30, 40, 256)  1024        spatial_dropout2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 15, 20, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 30, 40, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_18 (SpatialDr (None, 15, 20, 512)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 30, 40, 256)  590080      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 15, 20, 512)  2048        spatial_dropout2d_18[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_17 (SpatialDr (None, 30, 40, 256)  0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 15, 20, 512)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 30, 40, 256)  1024        spatial_dropout2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 15, 20, 256)  1179904     leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 30, 40, 256)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 15, 20, 256)  1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 30, 40, 1)    257         leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 15, 20, 256)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 30, 40, 1)    4           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 60, 80, 256)  590080      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 30, 40, 256)  0           leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 30, 40, 1)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_12 (SpatialDr (None, 60, 80, 256)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 30, 40, 256)  0           up_sampling2d[0][0]
#                                                                  leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 60, 80, 256)  1024        spatial_dropout2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 30, 40, 256)  590080      multiply[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 60, 80, 256)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_19 (SpatialDr (None, 30, 40, 256)  0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 60, 80, 256)  590080      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 30, 40, 256)  1024        spatial_dropout2d_19[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_13 (SpatialDr (None, 60, 80, 256)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 30, 40, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 60, 80, 256)  1024        spatial_dropout2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 30, 40, 256)  590080      leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 60, 80, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 30, 40, 256)  1024        conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 60, 80, 1)    257         leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 30, 40, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 60, 80, 1)    4           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 120, 160, 128 147584      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 60, 80, 256)  0           leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 60, 80, 1)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_8 (SpatialDro (None, 120, 160, 128 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 60, 80, 256)  0           up_sampling2d_1[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 120, 160, 128 512         spatial_dropout2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 60, 80, 256)  590080      multiply_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 120, 160, 128 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_20 (SpatialDr (None, 60, 80, 256)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 120, 160, 128 147584      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 60, 80, 256)  1024        spatial_dropout2d_20[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_9 (SpatialDro (None, 120, 160, 128 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 60, 80, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 120, 160, 128 512         spatial_dropout2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 60, 80, 128)  295040      leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 120, 160, 128 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 60, 80, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 120, 160, 1)  129         leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 60, 80, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 120, 160, 1)  4           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 240, 320, 64) 36928       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 120, 160, 128 0           leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 120, 160, 1)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 240, 320, 64) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 120, 160, 128 0           up_sampling2d_2[0][0]
#                                                                  leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 240, 320, 64) 256         spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 120, 160, 128 147584      multiply_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 240, 320, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_21 (SpatialDr (None, 120, 160, 128 0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 240, 320, 64) 36928       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 120, 160, 128 512         spatial_dropout2d_21[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_5 (SpatialDro (None, 240, 320, 64) 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 120, 160, 128 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 240, 320, 64) 256         spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 120, 160, 64) 73792       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 240, 320, 64) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 120, 160, 64) 256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 240, 320, 1)  65          leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 120, 160, 64) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 240, 320, 1)  4           conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 240, 320, 64) 0           leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 240, 320, 1)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 240, 320, 64) 0           up_sampling2d_3[0][0]
#                                                                  leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 240, 320, 64) 36928       multiply_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_22 (SpatialDr (None, 240, 320, 64) 0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 240, 320, 64) 256         spatial_dropout2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 240, 320, 64) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 240, 320, 32) 18464       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 240, 320, 32) 128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 240, 320, 32) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 480, 640, 32) 0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 480, 640, 38) 1254        up_sampling2d_4[0][0]
# ==================================================================================================
# Total params: 9,805,178
# Trainable params: 9,795,506
# Non-trainable params: 9,672
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model2, show_shapes=True, dpi=64)
# model.summary()

# %%
# tf.saved_model.save(model,  '/content/drive/MyDrive/experiment-layers/june-20-skip-layers/mymodel')
# tf.keras.models.load_model('/content/drive/MyDrive/experiment-layers/june-20-skip-layers/mymodel/')

# %%
#loss function 
# loss = tf.keras.losses.categorical_crossentropy(from_logits=True)
def binary_loss(y_true, y_pred):
    loss = binary_crossentropy(y_true, y_pred,from_logits=True)
    loss_value = tf.math.reduce_mean(loss,axis=[0])
    return loss_value
# loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True, )
# def cross_entropy_loss(y_true,y_pred):
#     return loss(y_true,y_pred)
def cross_entropy_loss(y_true,y_pred):
    loss = tf.nn.softmax_cross_entropy_with_logits(
    y_true, y_pred, axis=-1, name=None)
    return loss

def custom_metrics(y_true,y_pred,smooth=1):
    y_pred = tf.math.argmax(y_pred, axis=-1)
    # y_pred = tf.expand_dims(y_pred,axis=-1)
    y_pred = tf.one_hot(y_pred,38)
    y_true = y_true[:,:,:,1:38]
    y_pred= y_pred[:,:,:,1:38]
    intersection  = tf.math.reduce_sum((y_true*y_pred),axis = [1,2,3])
    union = (tf.math.reduce_sum(y_true,axis=[1,2,3])+tf.math.reduce_sum(y_pred,axis = [1,2,3])) - intersection
    return tf.math.reduce_mean((intersection+smooth)/(union+smooth),axis=0)
smooth = 1
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
# model=tf.keras.models.load_model( '/content/drive/MyDrive/experiment-layers/june-20-skip-layers/dropout/checkpoint/saved_model.pb',custom_objects={
#         'cross_entropy_loss': cross_entropy_loss ,'dice_coef': dice_coef,'custom_metrics':custom_metrics})
# model2.compile(loss = cross_entropy_loss,optimizer=Adam(learning_rate =.001),metrics=[custom_metrics])

# %%
# model.load_weights('/content/drive/MyDrive/experiment-layers/june-19-skip-layers/myfolder/checkpoint')

# %%
epoch=1
t_steps=train_size//16
v_steps=valid_size//16
val_custom_metrics = 0
for i in range(epoch):
  model2.fit(train_dataset,epochs= 1,steps_per_epoch=t_steps)
  loss = model2.evaluate(valid_dataset,steps=v_steps)
  print('val_loss : val_metrics ',loss[0],loss[1])
  if loss[1]>=val_custom_metrics:
    val_custom_metrics = loss[1]
    # tf.saved_model.save(model2,'/content/drive/MyDrive/training-daily/22June/5:30')
    model2.save('/content/drive/MyDrive/training-daily/22June/5:30',save_format='tf')
  tf.keras.backend.clear_session()
  gc.collect()
# Out:
# 1/1 [==============================] - 14s 14s/step - loss: 2.8262 - custom_metrics: 0.0406
# 1/1 [==============================] - 9s 9s/step - loss: 3.1582 - custom_metrics: 0.0747
# val_loss : val_metrics  3.158203125 0.07465235888957977
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/training-daily/22June/5:30/assets

# %%
# !nvidia-smi
# Out:
# Tue Jun 22 03:16:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    73W / 149W |  10904MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
dahal=tf.keras.models.load_model('/content/drive/MyDrive/training-daily/july21/kale6/',custom_objects={'cross_entropy_loss':cross_entropy_loss,'custom_metrics':custom_metrics})
dahal.compile(loss = cross_entropy_loss,optimizer=Adam(learning_rate =.001),metrics=[custom_metrics])

# %%
epoch=24
t_steps=train_size//16
v_steps=valid_size//16
val_custom_metrics = 0
for i in range(epoch):
  dahal.fit(train_dataset,epochs= 1,steps_per_epoch=t_steps)
  loss = dahal.evaluate(valid_dataset,steps=v_steps)
  print('val_loss : val_metrics ',loss[0],loss[1])
  if loss[1]>=val_custom_metrics:
    val_custom_metrics = loss[1]
    # tf.saved_model.save(model2,'/content/drive/MyDrive/training-daily/22June/5:30')
    dahal.save('/content/drive/MyDrive/training-daily/22June/kale6.1',save_format='tf')
  tf.keras.backend.clear_session()
  gc.collect()
# Out:
# 312/312 [==============================] - 2754s 9s/step - loss: 1.4525 - custom_metrics: 0.3620
# 62/62 [==============================] - 512s 8s/step - loss: 1.3917 - custom_metrics: 0.3779
# val_loss : val_metrics  1.391680359840393 0.3778594732284546
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/training-daily/22June/kale6.1/assets
# 312/312 [==============================] - 636s 2s/step - loss: 1.4223 - custom_metrics: 0.3679
# 62/62 [==============================] - 82s 1s/step - loss: 1.3730 - custom_metrics: 0.3963
# val_loss : val_metrics  1.3730311393737793 0.39628779888153076
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/training-daily/22June/kale6.1/assets
# 312/312 [==============================] - 638s 2s/step - loss: 1.4043 - custom_metrics: 0.3740
# 62/62 [==============================] - 82s 1s/step - loss: 1.3692 - custom_metrics: 0.3920
# val_loss : val_metrics  1.3691563606262207 0.39204633235931396
# 312/312 [==============================] - 637s 2s/step - loss: 1.3884 - custom_metrics: 0.3790
# 62/62 [==============================] - 82s 1s/step - loss: 1.3951 - custom_metrics: 0.3966
# val_loss : val_metrics  1.3951297998428345 0.39657750725746155
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/training-daily/22June/kale6.1/assets
# 312/312 [==============================] - 639s 2s/step - loss: 1.3797 - custom_metrics: 0.3821
# 62/62 [==============================] - 83s 1s/step - loss: 1.3623 - custom_metrics: 0.4009
# val_loss : val_metrics  1.3622889518737793 0.40091341733932495
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/training-daily/22June/kale6.1/assets
# 312/312 [==============================] - 638s 2s/step - loss: 1.3623 - custom_metrics: 0.3862
# 62/62 [==============================] - 82s 1s/step - loss: 1.3725 - custom_metrics: 0.4002
# val_loss : val_metrics  1.3725271224975586 0.40019139647483826
# 312/312 [==============================] - 634s 2s/step - loss: 1.3454 - custom_metrics: 0.3923
# 62/62 [==============================] - 82s 1s/step - loss: 1.3754 - custom_metrics: 0.3933
# val_loss : val_metrics  1.3753780126571655 0.3932633101940155
# 312/312 [==============================] - 635s 2s/step - loss: 1.3373 - custom_metrics: 0.3946
# 62/62 [==============================] - 82s 1s/step - loss: 1.3760 - custom_metrics: 0.3973
# val_loss : val_metrics  1.3760080337524414 0.3973339796066284
# 312/312 [==============================] - 635s 2s/step - loss: 1.3189 - custom_metrics: 0.3988
# 62/62 [==============================] - 81s 1s/step - loss: 1.4148 - custom_metrics: 0.3974
# val_loss : val_metrics  1.4147870540618896 0.3973521292209625
# 312/312 [==============================] - 634s 2s/step - loss: 1.3036 - custom_metrics: 0.4047
# 62/62 [==============================] - 81s 1s/step - loss: 1.3570 - custom_metrics: 0.4110
# val_loss : val_metrics  1.357012391090393 0.4109635651111603
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/training-daily/22June/kale6.1/assets
# 312/312 [==============================] - 633s 2s/step - loss: 1.2897 - custom_metrics: 0.4090
# 62/62 [==============================] - 81s 1s/step - loss: 1.3725 - custom_metrics: 0.4035
# val_loss : val_metrics  1.3724640607833862 0.40352484583854675
# 312/312 [==============================] - 633s 2s/step - loss: 1.2778 - custom_metrics: 0.4121
# 62/62 [==============================] - 81s 1s/step - loss: 1.3705 - custom_metrics: 0.4068
# val_loss : val_metrics  1.370526671409607 0.40678223967552185
# 312/312 [==============================] - 634s 2s/step - loss: 1.2614 - custom_metrics: 0.4170
# 62/62 [==============================] - 81s 1s/step - loss: 1.3677 - custom_metrics: 0.4093
# val_loss : val_metrics  1.3676600456237793 0.4093192219734192
# 312/312 [==============================] - 633s 2s/step - loss: 1.2463 - custom_metrics: 0.4228
# 62/62 [==============================] - 81s 1s/step - loss: 1.3797 - custom_metrics: 0.4024
# val_loss : val_metrics  1.3796937465667725 0.4023987650871277
# 312/312 [==============================] - 633s 2s/step - loss: 1.2302 - custom_metrics: 0.4264
# 62/62 [==============================] - 81s 1s/step - loss: 1.3853 - custom_metrics: 0.4058
# val_loss : val_metrics  1.385332703590393 0.4058227837085724
# 312/312 [==============================] - 634s 2s/step - loss: 1.2177 - custom_metrics: 0.4330
# 62/62 [==============================] - 81s 1s/step - loss: 1.3949 - custom_metrics: 0.4024
# val_loss : val_metrics  1.3948620557785034 0.4023902416229248
# 312/312 [==============================] - 634s 2s/step - loss: 1.2009 - custom_metrics: 0.4372
# 62/62 [==============================] - 81s 1s/step - loss: 1.3849 - custom_metrics: 0.4053
# val_loss : val_metrics  1.3849388360977173 0.40530192852020264
# 312/312 [==============================] - 634s 2s/step - loss: 1.1855 - custom_metrics: 0.4415
# 62/62 [==============================] - 81s 1s/step - loss: 1.4114 - custom_metrics: 0.3954
# val_loss : val_metrics  1.4113848209381104 0.39539656043052673
# 312/312 [==============================] - 633s 2s/step - loss: 1.1716 - custom_metrics: 0.4467
# 62/62 [==============================] - 81s 1s/step - loss: 1.4016 - custom_metrics: 0.4017
# val_loss : val_metrics  1.4016034603118896 0.4016561806201935
# 312/312 [==============================] - 635s 2s/step - loss: 1.1576 - custom_metrics: 0.4510
# 62/62 [==============================] - 82s 1s/step - loss: 1.4237 - custom_metrics: 0.3965
# val_loss : val_metrics  1.4236863851547241 0.3965008854866028
# 312/312 [==============================] - 636s 2s/step - loss: 1.1403 - custom_metrics: 0.4581
# 62/62 [==============================] - 81s 1s/step - loss: 1.4289 - custom_metrics: 0.3893
# val_loss : val_metrics  1.4289472103118896 0.3892518877983093
# 312/312 [==============================] - 635s 2s/step - loss: 1.1204 - custom_metrics: 0.4645
# 62/62 [==============================] - 81s 1s/step - loss: 1.4287 - custom_metrics: 0.4025
# val_loss : val_metrics  1.4286794662475586 0.4025011360645294
# 312/312 [==============================] - 636s 2s/step - loss: 1.1066 - custom_metrics: 0.4697
# 62/62 [==============================] - 82s 1s/step - loss: 1.4258 - custom_metrics: 0.3938
# val_loss : val_metrics  1.4257655143737793 0.39381277561187744
# 312/312 [==============================] - 633s 2s/step - loss: 1.0888 - custom_metrics: 0.4751
# 62/62 [==============================] - 81s 1s/step - loss: 1.4966 - custom_metrics: 0.3907
# val_loss : val_metrics  1.4965977668762207 0.3906622529029846

# %%
def read_image(path):
    x = cv.imread(path, cv.IMREAD_COLOR)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_AREA)
    x = x/255.0
    x=tf.cast(x,dtype=tf.float32)
    return x

def read_mask(path):
    x = cv.imread(path, cv.IMREAD_GRAYSCALE)
    x = cv.resize(x,(640,480),interpolation=cv.INTER_AREA)
    x = to_categorical(x,num_classes=no_classes+1)
    x = x[:,:,:]
    # x = np.expand_dims(x, axis=-1)
    # x=np.concatenate([x,x],axis=-1)
    x=tf.cast(x,dtype=tf.float32)
    return x
# def custom_metrics(y_true,y_pred,smooth=1):
#     y_pred = tf.math.argmax(y_pred, axis=-1)
#     # y_pred = tf.expand_dims(y_pred,axis=-1)
#     y_pred = tf.one_hot(y_pred,38)
#     y_true = y_true[:,:,:,1:38]
#     y_pred= y_pred[:,:,:,1:38]
#     intersection  = tf.math.reduce_sum((y_true*y_pred),axis = [1,2,3])
#     union = tf.math.reduce_sum(y_true,axis=[1,2,3])+tf.math.reduce_sum(y_pred,axis = [1,2,3]) - intersection 
#     return tf.math.reduce_mean((intersection+smooth)/(union+smooth),axis=0)
def load_data(images,masks):
    length = 1990
    iou=0
    for i,(image,mask) in enumerate(zip(images,masks)):
    
      img = read_image(image)
      mas = read_mask(mask)
      img = np.expand_dims(img,0)
      mas = np.expand_dims(mas,0)
      prediction = dahal.predict(img)
      iou += custom_metrics(mas,prediction)
      print(i,iou)
    return iou/length
no_classes=37
print(len(test_x))
x=load_data(test_x,test_y)
print('*****************************************************************************************************************')
x
# Out:
# 1990
# 0 tf.Tensor(0.45461395, shape=(), dtype=float32)
# 1 tf.Tensor(0.98106647, shape=(), dtype=float32)
# 2 tf.Tensor(1.2768958, shape=(), dtype=float32)
# 3 tf.Tensor(1.9688873, shape=(), dtype=float32)
# 4 tf.Tensor(2.2544754, shape=(), dtype=float32)
# 5 tf.Tensor(2.419525, shape=(), dtype=float32)
# 6 tf.Tensor(3.0369987, shape=(), dtype=float32)
# 7 tf.Tensor(3.0370605, shape=(), dtype=float32)
# 8 tf.Tensor(3.3165097, shape=(), dtype=float32)
# 9 tf.Tensor(3.6460984, shape=(), dtype=float32)
# 10 tf.Tensor(3.7773514, shape=(), dtype=float32)
# 11 tf.Tensor(4.102548, shape=(), dtype=float32)
# 12 tf.Tensor(4.8369994, shape=(), dtype=float32)
# 13 tf.Tensor(5.31058, shape=(), dtype=float32)
# 14 tf.Tensor(5.764444, shape=(), dtype=float32)
# 15 tf.Tensor(6.0813303, shape=(), dtype=float32)
# 16 tf.Tensor(6.387572, shape=(), dtype=float32)
# 17 tf.Tensor(7.2806244, shape=(), dtype=float32)
# 18 tf.Tensor(7.6512184, shape=(), dtype=float32)
# 19 tf.Tensor(7.901015, shape=(), dtype=float32)
# 20 tf.Tensor(8.785809, shape=(), dtype=float32)
# 21 tf.Tensor(9.066233, shape=(), dtype=float32)
# 22 tf.Tensor(9.507268, shape=(), dtype=float32)
# 23 tf.Tensor(9.756324, shape=(), dtype=float32)
# 24 tf.Tensor(10.313909, shape=(), dtype=float32)
# 25 tf.Tensor(10.654536, shape=(), dtype=float32)
# 26 tf.Tensor(11.050554, shape=(), dtype=float32)
# 27 tf.Tensor(11.181914, shape=(), dtype=float32)
# 28 tf.Tensor(11.349854, shape=(), dtype=float32)
# 29 tf.Tensor(11.6117325, shape=(), dtype=float32)
# 30 tf.Tensor(11.855081, shape=(), dtype=float32)
# 31 tf.Tensor(12.032765, shape=(), dtype=float32)
# 32 tf.Tensor(12.319879, shape=(), dtype=float32)
# 33 tf.Tensor(12.930772, shape=(), dtype=float32)
# 34 tf.Tensor(12.933031, shape=(), dtype=float32)
# 35 tf.Tensor(13.546882, shape=(), dtype=float32)
# 36 tf.Tensor(13.922975, shape=(), dtype=float32)
# 37 tf.Tensor(14.448417, shape=(), dtype=float32)
# 38 tf.Tensor(14.996559, shape=(), dtype=float32)
# 39 tf.Tensor(14.996883, shape=(), dtype=float32)
# 40 tf.Tensor(15.309608, shape=(), dtype=float32)
# 41 tf.Tensor(16.046537, shape=(), dtype=float32)
# 42 tf.Tensor(16.144428, shape=(), dtype=float32)
# 43 tf.Tensor(16.23799, shape=(), dtype=float32)
# 44 tf.Tensor(16.374687, shape=(), dtype=float32)
# 45 tf.Tensor(16.834238, shape=(), dtype=float32)
# 46 tf.Tensor(16.91053, shape=(), dtype=float32)
# 47 tf.Tensor(16.933079, shape=(), dtype=float32)
# 48 tf.Tensor(17.23433, shape=(), dtype=float32)
# 49 tf.Tensor(17.623627, shape=(), dtype=float32)
# 50 tf.Tensor(17.736696, shape=(), dtype=float32)
# 51 tf.Tensor(18.359001, shape=(), dtype=float32)
# 52 tf.Tensor(18.559332, shape=(), dtype=float32)
# 53 tf.Tensor(18.87211, shape=(), dtype=float32)
# 54 tf.Tensor(19.41697, shape=(), dtype=float32)
# 55 tf.Tensor(19.431225, shape=(), dtype=float32)
# 56 tf.Tensor(20.027138, shape=(), dtype=float32)
# 57 tf.Tensor(20.265993, shape=(), dtype=float32)
# 58 tf.Tensor(20.82605, shape=(), dtype=float32)
# 59 tf.Tensor(20.849379, shape=(), dtype=float32)
# 60 tf.Tensor(20.853188, shape=(), dtype=float32)
# 61 tf.Tensor(21.130182, shape=(), dtype=float32)
# 62 tf.Tensor(21.477924, shape=(), dtype=float32)
# 63 tf.Tensor(21.935965, shape=(), dtype=float32)
# 64 tf.Tensor(22.493834, shape=(), dtype=float32)
# 65 tf.Tensor(22.959684, shape=(), dtype=float32)
# 66 tf.Tensor(23.318995, shape=(), dtype=float32)
# 67 tf.Tensor(23.54865, shape=(), dtype=float32)
# 68 tf.Tensor(24.125305, shape=(), dtype=float32)
# 69 tf.Tensor(24.757835, shape=(), dtype=float32)
# 70 tf.Tensor(25.255964, shape=(), dtype=float32)
# 71 tf.Tensor(25.764874, shape=(), dtype=float32)
# 72 tf.Tensor(26.49397, shape=(), dtype=float32)
# 73 tf.Tensor(26.757872, shape=(), dtype=float32)
# 74 tf.Tensor(27.074045, shape=(), dtype=float32)
# 75 tf.Tensor(27.35746, shape=(), dtype=float32)
# 76 tf.Tensor(27.618153, shape=(), dtype=float32)
# 77 tf.Tensor(28.355537, shape=(), dtype=float32)
# 78 tf.Tensor(28.713568, shape=(), dtype=float32)
# 79 tf.Tensor(29.323793, shape=(), dtype=float32)
# 80 tf.Tensor(29.984343, shape=(), dtype=float32)
# 81 tf.Tensor(30.718065, shape=(), dtype=float32)
# 82 tf.Tensor(31.278753, shape=(), dtype=float32)
# 83 tf.Tensor(31.826113, shape=(), dtype=float32)
# 84 tf.Tensor(31.956205, shape=(), dtype=float32)
# 85 tf.Tensor(32.502575, shape=(), dtype=float32)
# 86 tf.Tensor(33.05735, shape=(), dtype=float32)
# 87 tf.Tensor(33.79071, shape=(), dtype=float32)
# 88 tf.Tensor(34.295033, shape=(), dtype=float32)
# 89 tf.Tensor(34.65425, shape=(), dtype=float32)
# 90 tf.Tensor(35.244633, shape=(), dtype=float32)
# 91 tf.Tensor(35.511917, shape=(), dtype=float32)
# 92 tf.Tensor(36.012615, shape=(), dtype=float32)
# 93 tf.Tensor(36.45301, shape=(), dtype=float32)
# 94 tf.Tensor(36.684467, shape=(), dtype=float32)
# 95 tf.Tensor(37.2517, shape=(), dtype=float32)
# 96 tf.Tensor(38.087723, shape=(), dtype=float32)
# 97 tf.Tensor(38.369484, shape=(), dtype=float32)
# 98 tf.Tensor(38.648006, shape=(), dtype=float32)
# 99 tf.Tensor(38.781734, shape=(), dtype=float32)
# 100 tf.Tensor(38.99357, shape=(), dtype=float32)
# 101 tf.Tensor(39.399303, shape=(), dtype=float32)
# 102 tf.Tensor(39.96309, shape=(), dtype=float32)
# 103 tf.Tensor(40.776627, shape=(), dtype=float32)
# 104 tf.Tensor(40.99614, shape=(), dtype=float32)
# 105 tf.Tensor(41.31603, shape=(), dtype=float32)
# 106 tf.Tensor(41.780422, shape=(), dtype=float32)
# 107 tf.Tensor(42.038765, shape=(), dtype=float32)
# 108 tf.Tensor(42.458427, shape=(), dtype=float32)
# 109 tf.Tensor(42.815258, shape=(), dtype=float32)
# 110 tf.Tensor(43.007507, shape=(), dtype=float32)
# 111 tf.Tensor(43.59177, shape=(), dtype=float32)
# 112 tf.Tensor(43.959602, shape=(), dtype=float32)
# 113 tf.Tensor(44.703438, shape=(), dtype=float32)
# 114 tf.Tensor(45.005863, shape=(), dtype=float32)
# 115 tf.Tensor(45.59762, shape=(), dtype=float32)
# 116 tf.Tensor(46.133106, shape=(), dtype=float32)
# 117 tf.Tensor(46.570744, shape=(), dtype=float32)
# 118 tf.Tensor(47.383846, shape=(), dtype=float32)
# 119 tf.Tensor(47.60778, shape=(), dtype=float32)
# 120 tf.Tensor(48.298622, shape=(), dtype=float32)
# 121 tf.Tensor(48.82502, shape=(), dtype=float32)
# 122 tf.Tensor(49.449047, shape=(), dtype=float32)
# 123 tf.Tensor(49.845688, shape=(), dtype=float32)
# 124 tf.Tensor(50.448273, shape=(), dtype=float32)
# 125 tf.Tensor(51.06133, shape=(), dtype=float32)
# 126 tf.Tensor(51.163517, shape=(), dtype=float32)
# 127 tf.Tensor(51.82942, shape=(), dtype=float32)
# 128 tf.Tensor(52.449356, shape=(), dtype=float32)
# 129 tf.Tensor(52.488777, shape=(), dtype=float32)
# 130 tf.Tensor(52.660152, shape=(), dtype=float32)
# 131 tf.Tensor(52.751873, shape=(), dtype=float32)
# 132 tf.Tensor(52.977905, shape=(), dtype=float32)
# 133 tf.Tensor(53.54792, shape=(), dtype=float32)
# 134 tf.Tensor(53.54812, shape=(), dtype=float32)
# 135 tf.Tensor(53.676693, shape=(), dtype=float32)
# 136 tf.Tensor(53.855804, shape=(), dtype=float32)
# 137 tf.Tensor(54.516293, shape=(), dtype=float32)
# 138 tf.Tensor(55.082863, shape=(), dtype=float32)
# 139 tf.Tensor(55.35609, shape=(), dtype=float32)
# 140 tf.Tensor(55.629032, shape=(), dtype=float32)
# 141 tf.Tensor(56.141438, shape=(), dtype=float32)
# 142 tf.Tensor(56.59831, shape=(), dtype=float32)
# 143 tf.Tensor(56.84008, shape=(), dtype=float32)
# 144 tf.Tensor(57.21705, shape=(), dtype=float32)
# 145 tf.Tensor(57.62721, shape=(), dtype=float32)
# 146 tf.Tensor(57.668888, shape=(), dtype=float32)
# 147 tf.Tensor(57.95794, shape=(), dtype=float32)
# 148 tf.Tensor(57.95796, shape=(), dtype=float32)
# 149 tf.Tensor(58.072773, shape=(), dtype=float32)
# 150 tf.Tensor(58.6485, shape=(), dtype=float32)
# 151 tf.Tensor(59.273212, shape=(), dtype=float32)
# 152 tf.Tensor(59.98646, shape=(), dtype=float32)
# 153 tf.Tensor(59.986862, shape=(), dtype=float32)
# 154 tf.Tensor(60.96724, shape=(), dtype=float32)
# 155 tf.Tensor(61.576824, shape=(), dtype=float32)
# 156 tf.Tensor(61.72168, shape=(), dtype=float32)
# 157 tf.Tensor(62.09504, shape=(), dtype=float32)
# 158 tf.Tensor(62.225323, shape=(), dtype=float32)
# 159 tf.Tensor(62.603046, shape=(), dtype=float32)
# 160 tf.Tensor(63.01795, shape=(), dtype=float32)
# 161 tf.Tensor(63.124767, shape=(), dtype=float32)
# 162 tf.Tensor(63.463436, shape=(), dtype=float32)
# 163 tf.Tensor(64.1443, shape=(), dtype=float32)
# 164 tf.Tensor(64.45739, shape=(), dtype=float32)
# 165 tf.Tensor(64.88176, shape=(), dtype=float32)
# 166 tf.Tensor(65.08893, shape=(), dtype=float32)
# 167 tf.Tensor(65.54129, shape=(), dtype=float32)
# 168 tf.Tensor(65.54333, shape=(), dtype=float32)
# 169 tf.Tensor(66.07618, shape=(), dtype=float32)
# 170 tf.Tensor(66.25295, shape=(), dtype=float32)
# 171 tf.Tensor(66.81632, shape=(), dtype=float32)
# 172 tf.Tensor(67.304985, shape=(), dtype=float32)
# 173 tf.Tensor(67.3101, shape=(), dtype=float32)
# 174 tf.Tensor(68.04445, shape=(), dtype=float32)
# 175 tf.Tensor(68.27827, shape=(), dtype=float32)
# 176 tf.Tensor(68.53752, shape=(), dtype=float32)
# 177 tf.Tensor(69.14024, shape=(), dtype=float32)
# 178 tf.Tensor(69.54401, shape=(), dtype=float32)
# 179 tf.Tensor(70.08146, shape=(), dtype=float32)
# 180 tf.Tensor(70.91118, shape=(), dtype=float32)
# 181 tf.Tensor(71.07276, shape=(), dtype=float32)
# 182 tf.Tensor(71.58219, shape=(), dtype=float32)
# 183 tf.Tensor(71.5822, shape=(), dtype=float32)
# 184 tf.Tensor(71.72828, shape=(), dtype=float32)
# 185 tf.Tensor(71.83952, shape=(), dtype=float32)
# 186 tf.Tensor(72.49307, shape=(), dtype=float32)
# 187 tf.Tensor(72.79628, shape=(), dtype=float32)
# 188 tf.Tensor(73.30886, shape=(), dtype=float32)
# 189 tf.Tensor(73.39166, shape=(), dtype=float32)
# 190 tf.Tensor(74.04026, shape=(), dtype=float32)
# 191 tf.Tensor(74.222015, shape=(), dtype=float32)
# 192 tf.Tensor(74.77891, shape=(), dtype=float32)
# 193 tf.Tensor(74.94067, shape=(), dtype=float32)
# 194 tf.Tensor(75.55431, shape=(), dtype=float32)
# 195 tf.Tensor(75.98906, shape=(), dtype=float32)
# 196 tf.Tensor(76.219215, shape=(), dtype=float32)
# 197 tf.Tensor(76.50679, shape=(), dtype=float32)
# 198 tf.Tensor(77.13601, shape=(), dtype=float32)
# 199 tf.Tensor(77.30218, shape=(), dtype=float32)
# 200 tf.Tensor(77.95035, shape=(), dtype=float32)
# 201 tf.Tensor(77.950356, shape=(), dtype=float32)
# 202 tf.Tensor(78.37013, shape=(), dtype=float32)
# 203 tf.Tensor(78.618866, shape=(), dtype=float32)
# 204 tf.Tensor(79.19441, shape=(), dtype=float32)
# 205 tf.Tensor(79.378876, shape=(), dtype=float32)
# 206 tf.Tensor(79.464584, shape=(), dtype=float32)
# 207 tf.Tensor(79.46461, shape=(), dtype=float32)
# 208 tf.Tensor(79.60146, shape=(), dtype=float32)
# 209 tf.Tensor(80.25429, shape=(), dtype=float32)
# 210 tf.Tensor(80.36869, shape=(), dtype=float32)
# 211 tf.Tensor(81.02619, shape=(), dtype=float32)
# 212 tf.Tensor(81.31739, shape=(), dtype=float32)
# 213 tf.Tensor(81.35178, shape=(), dtype=float32)
# 214 tf.Tensor(81.67554, shape=(), dtype=float32)
# 215 tf.Tensor(82.19763, shape=(), dtype=float32)
# 216 tf.Tensor(82.66984, shape=(), dtype=float32)
# 217 tf.Tensor(82.85565, shape=(), dtype=float32)
# 218 tf.Tensor(83.17056, shape=(), dtype=float32)
# 219 tf.Tensor(83.352745, shape=(), dtype=float32)
# 220 tf.Tensor(84.01721, shape=(), dtype=float32)
# 221 tf.Tensor(84.28407, shape=(), dtype=float32)
# 222 tf.Tensor(84.660034, shape=(), dtype=float32)
# 223 tf.Tensor(85.33648, shape=(), dtype=float32)
# 224 tf.Tensor(85.59947, shape=(), dtype=float32)
# 225 tf.Tensor(85.89946, shape=(), dtype=float32)
# 226 tf.Tensor(85.936516, shape=(), dtype=float32)
# 227 tf.Tensor(86.52887, shape=(), dtype=float32)
# 228 tf.Tensor(86.76181, shape=(), dtype=float32)
# 229 tf.Tensor(86.98946, shape=(), dtype=float32)
# 230 tf.Tensor(87.00919, shape=(), dtype=float32)
# 231 tf.Tensor(87.447426, shape=(), dtype=float32)
# 232 tf.Tensor(87.561424, shape=(), dtype=float32)
# 233 tf.Tensor(87.800766, shape=(), dtype=float32)
# 234 tf.Tensor(88.0216, shape=(), dtype=float32)
# 235 tf.Tensor(88.30707, shape=(), dtype=float32)
# 236 tf.Tensor(88.553314, shape=(), dtype=float32)
# 237 tf.Tensor(88.9387, shape=(), dtype=float32)
# 238 tf.Tensor(89.304794, shape=(), dtype=float32)
# 239 tf.Tensor(89.731346, shape=(), dtype=float32)
# 240 tf.Tensor(90.10224, shape=(), dtype=float32)
# 241 tf.Tensor(90.684166, shape=(), dtype=float32)
# 242 tf.Tensor(90.98248, shape=(), dtype=float32)
# 243 tf.Tensor(91.28772, shape=(), dtype=float32)
# 244 tf.Tensor(91.79632, shape=(), dtype=float32)
# 245 tf.Tensor(92.16422, shape=(), dtype=float32)
# 246 tf.Tensor(92.24626, shape=(), dtype=float32)
# 247 tf.Tensor(92.76193, shape=(), dtype=float32)
# 248 tf.Tensor(92.84845, shape=(), dtype=float32)
# 249 tf.Tensor(93.312645, shape=(), dtype=float32)
# 250 tf.Tensor(93.31546, shape=(), dtype=float32)
# 251 tf.Tensor(93.57453, shape=(), dtype=float32)
# 252 tf.Tensor(94.26292, shape=(), dtype=float32)
# 253 tf.Tensor(94.982765, shape=(), dtype=float32)
# 254 tf.Tensor(95.78695, shape=(), dtype=float32)
# 255 tf.Tensor(96.15803, shape=(), dtype=float32)
# 256 tf.Tensor(96.34093, shape=(), dtype=float32)
# 257 tf.Tensor(96.75689, shape=(), dtype=float32)
# 258 tf.Tensor(97.132675, shape=(), dtype=float32)
# 259 tf.Tensor(97.77833, shape=(), dtype=float32)
# 260 tf.Tensor(97.88421, shape=(), dtype=float32)
# 261 tf.Tensor(98.264435, shape=(), dtype=float32)
# 262 tf.Tensor(98.684166, shape=(), dtype=float32)
# 263 tf.Tensor(99.432014, shape=(), dtype=float32)
# 264 tf.Tensor(99.92194, shape=(), dtype=float32)
# 265 tf.Tensor(100.411026, shape=(), dtype=float32)
# 266 tf.Tensor(100.54132, shape=(), dtype=float32)
# 267 tf.Tensor(101.17761, shape=(), dtype=float32)
# 268 tf.Tensor(101.786476, shape=(), dtype=float32)
# 269 tf.Tensor(102.37491, shape=(), dtype=float32)
# 270 tf.Tensor(102.656006, shape=(), dtype=float32)
# 271 tf.Tensor(102.87158, shape=(), dtype=float32)
# 272 tf.Tensor(103.005356, shape=(), dtype=float32)
# 273 tf.Tensor(103.25201, shape=(), dtype=float32)
# 274 tf.Tensor(103.443665, shape=(), dtype=float32)
# 275 tf.Tensor(103.744736, shape=(), dtype=float32)
# 276 tf.Tensor(103.800545, shape=(), dtype=float32)
# 277 tf.Tensor(104.00171, shape=(), dtype=float32)
# 278 tf.Tensor(104.223656, shape=(), dtype=float32)
# 279 tf.Tensor(104.38703, shape=(), dtype=float32)
# 280 tf.Tensor(104.603386, shape=(), dtype=float32)
# 281 tf.Tensor(105.06488, shape=(), dtype=float32)
# 282 tf.Tensor(105.381744, shape=(), dtype=float32)
# 283 tf.Tensor(105.55521, shape=(), dtype=float32)
# 284 tf.Tensor(106.10559, shape=(), dtype=float32)
# 285 tf.Tensor(106.45409, shape=(), dtype=float32)
# 286 tf.Tensor(106.911514, shape=(), dtype=float32)
# 287 tf.Tensor(107.261406, shape=(), dtype=float32)
# 288 tf.Tensor(107.93088, shape=(), dtype=float32)
# 289 tf.Tensor(108.25759, shape=(), dtype=float32)
# 290 tf.Tensor(108.96569, shape=(), dtype=float32)
# 291 tf.Tensor(109.02764, shape=(), dtype=float32)
# 292 tf.Tensor(109.56623, shape=(), dtype=float32)
# 293 tf.Tensor(109.64199, shape=(), dtype=float32)
# 294 tf.Tensor(110.04708, shape=(), dtype=float32)
# 295 tf.Tensor(110.32108, shape=(), dtype=float32)
# 296 tf.Tensor(110.87924, shape=(), dtype=float32)
# 297 tf.Tensor(111.13887, shape=(), dtype=float32)
# 298 tf.Tensor(111.446976, shape=(), dtype=float32)
# 299 tf.Tensor(111.81282, shape=(), dtype=float32)
# 300 tf.Tensor(112.3519, shape=(), dtype=float32)
# 301 tf.Tensor(112.7805, shape=(), dtype=float32)
# 302 tf.Tensor(113.01628, shape=(), dtype=float32)
# 303 tf.Tensor(113.56574, shape=(), dtype=float32)
# 304 tf.Tensor(113.80958, shape=(), dtype=float32)
# 305 tf.Tensor(114.0062, shape=(), dtype=float32)
# 306 tf.Tensor(114.092926, shape=(), dtype=float32)
# 307 tf.Tensor(114.72197, shape=(), dtype=float32)
# 308 tf.Tensor(115.10572, shape=(), dtype=float32)
# 309 tf.Tensor(115.319885, shape=(), dtype=float32)
# 310 tf.Tensor(115.54504, shape=(), dtype=float32)
# 311 tf.Tensor(115.78546, shape=(), dtype=float32)
# 312 tf.Tensor(116.39306, shape=(), dtype=float32)
# 313 tf.Tensor(116.84188, shape=(), dtype=float32)
# 314 tf.Tensor(117.12261, shape=(), dtype=float32)
# 315 tf.Tensor(117.62796, shape=(), dtype=float32)
# 316 tf.Tensor(118.13379, shape=(), dtype=float32)
# 317 tf.Tensor(118.5038, shape=(), dtype=float32)
# 318 tf.Tensor(119.0506, shape=(), dtype=float32)
# 319 tf.Tensor(119.37222, shape=(), dtype=float32)
# 320 tf.Tensor(120.053894, shape=(), dtype=float32)
# 321 tf.Tensor(120.42387, shape=(), dtype=float32)
# 322 tf.Tensor(120.69722, shape=(), dtype=float32)
# 323 tf.Tensor(121.198235, shape=(), dtype=float32)
# 324 tf.Tensor(121.833954, shape=(), dtype=float32)
# 325 tf.Tensor(122.01729, shape=(), dtype=float32)
# 326 tf.Tensor(122.58015, shape=(), dtype=float32)
# 327 tf.Tensor(122.97479, shape=(), dtype=float32)
# 328 tf.Tensor(123.391075, shape=(), dtype=float32)
# 329 tf.Tensor(123.76889, shape=(), dtype=float32)
# 330 tf.Tensor(124.312645, shape=(), dtype=float32)
# 331 tf.Tensor(125.115395, shape=(), dtype=float32)
# 332 tf.Tensor(125.707146, shape=(), dtype=float32)
# 333 tf.Tensor(125.804, shape=(), dtype=float32)
# 334 tf.Tensor(125.821236, shape=(), dtype=float32)
# 335 tf.Tensor(126.24917, shape=(), dtype=float32)
# 336 tf.Tensor(126.4242, shape=(), dtype=float32)
# 337 tf.Tensor(126.78455, shape=(), dtype=float32)
# 338 tf.Tensor(127.13121, shape=(), dtype=float32)
# 339 tf.Tensor(127.58989, shape=(), dtype=float32)
# 340 tf.Tensor(127.94881, shape=(), dtype=float32)
# 341 tf.Tensor(127.948944, shape=(), dtype=float32)
# 342 tf.Tensor(128.39436, shape=(), dtype=float32)
# 343 tf.Tensor(128.65845, shape=(), dtype=float32)
# 344 tf.Tensor(129.20831, shape=(), dtype=float32)
# 345 tf.Tensor(129.35982, shape=(), dtype=float32)
# 346 tf.Tensor(129.67339, shape=(), dtype=float32)
# 347 tf.Tensor(129.98804, shape=(), dtype=float32)
# 348 tf.Tensor(130.41072, shape=(), dtype=float32)
# 349 tf.Tensor(130.97441, shape=(), dtype=float32)
# 350 tf.Tensor(131.38011, shape=(), dtype=float32)
# 351 tf.Tensor(131.5519, shape=(), dtype=float32)
# 352 tf.Tensor(131.81934, shape=(), dtype=float32)
# 353 tf.Tensor(131.93678, shape=(), dtype=float32)
# 354 tf.Tensor(131.98784, shape=(), dtype=float32)
# 355 tf.Tensor(132.0825, shape=(), dtype=float32)
# 356 tf.Tensor(132.26428, shape=(), dtype=float32)
# 357 tf.Tensor(132.62221, shape=(), dtype=float32)
# 358 tf.Tensor(133.11111, shape=(), dtype=float32)
# 359 tf.Tensor(133.4773, shape=(), dtype=float32)
# 360 tf.Tensor(133.6384, shape=(), dtype=float32)
# 361 tf.Tensor(133.98863, shape=(), dtype=float32)
# 362 tf.Tensor(134.5894, shape=(), dtype=float32)
# 363 tf.Tensor(135.20433, shape=(), dtype=float32)
# 364 tf.Tensor(135.88211, shape=(), dtype=float32)
# 365 tf.Tensor(136.4307, shape=(), dtype=float32)
# 366 tf.Tensor(136.56216, shape=(), dtype=float32)
# 367 tf.Tensor(136.95653, shape=(), dtype=float32)
# 368 tf.Tensor(137.11629, shape=(), dtype=float32)
# 369 tf.Tensor(137.47363, shape=(), dtype=float32)
# 370 tf.Tensor(138.09744, shape=(), dtype=float32)
# 371 tf.Tensor(138.19287, shape=(), dtype=float32)
# 372 tf.Tensor(138.5233, shape=(), dtype=float32)
# 373 tf.Tensor(138.78358, shape=(), dtype=float32)
# 374 tf.Tensor(139.15332, shape=(), dtype=float32)
# 375 tf.Tensor(139.18457, shape=(), dtype=float32)
# 376 tf.Tensor(139.40846, shape=(), dtype=float32)
# 377 tf.Tensor(139.87494, shape=(), dtype=float32)
# 378 tf.Tensor(140.42978, shape=(), dtype=float32)
# 379 tf.Tensor(140.42993, shape=(), dtype=float32)
# 380 tf.Tensor(141.1568, shape=(), dtype=float32)
# 381 tf.Tensor(141.54564, shape=(), dtype=float32)
# 382 tf.Tensor(141.65665, shape=(), dtype=float32)
# 383 tf.Tensor(141.6696, shape=(), dtype=float32)
# 384 tf.Tensor(141.84738, shape=(), dtype=float32)
# 385 tf.Tensor(142.37613, shape=(), dtype=float32)
# 386 tf.Tensor(142.79778, shape=(), dtype=float32)
# 387 tf.Tensor(143.33372, shape=(), dtype=float32)
# 388 tf.Tensor(143.90414, shape=(), dtype=float32)
# 389 tf.Tensor(144.3834, shape=(), dtype=float32)
# 390 tf.Tensor(144.71239, shape=(), dtype=float32)
# 391 tf.Tensor(145.12285, shape=(), dtype=float32)
# 392 tf.Tensor(145.53523, shape=(), dtype=float32)
# 393 tf.Tensor(146.14034, shape=(), dtype=float32)
# 394 tf.Tensor(146.57181, shape=(), dtype=float32)
# 395 tf.Tensor(146.94008, shape=(), dtype=float32)
# 396 tf.Tensor(147.2575, shape=(), dtype=float32)
# 397 tf.Tensor(147.59799, shape=(), dtype=float32)
# 398 tf.Tensor(147.7353, shape=(), dtype=float32)
# 399 tf.Tensor(148.45361, shape=(), dtype=float32)
# 400 tf.Tensor(148.67851, shape=(), dtype=float32)
# 401 tf.Tensor(148.95537, shape=(), dtype=float32)
# 402 tf.Tensor(149.26535, shape=(), dtype=float32)
# 403 tf.Tensor(149.40071, shape=(), dtype=float32)
# 404 tf.Tensor(150.09232, shape=(), dtype=float32)
# 405 tf.Tensor(150.57222, shape=(), dtype=float32)
# 406 tf.Tensor(151.0263, shape=(), dtype=float32)
# 407 tf.Tensor(151.09888, shape=(), dtype=float32)
# 408 tf.Tensor(151.4911, shape=(), dtype=float32)
# 409 tf.Tensor(151.94965, shape=(), dtype=float32)
# 410 tf.Tensor(152.49586, shape=(), dtype=float32)
# 411 tf.Tensor(153.36426, shape=(), dtype=float32)
# 412 tf.Tensor(153.7107, shape=(), dtype=float32)
# 413 tf.Tensor(153.72795, shape=(), dtype=float32)
# 414 tf.Tensor(154.16849, shape=(), dtype=float32)
# 415 tf.Tensor(154.67392, shape=(), dtype=float32)
# 416 tf.Tensor(155.2746, shape=(), dtype=float32)
# 417 tf.Tensor(155.61383, shape=(), dtype=float32)
# 418 tf.Tensor(155.84482, shape=(), dtype=float32)
# 419 tf.Tensor(155.84555, shape=(), dtype=float32)
# 420 tf.Tensor(156.13347, shape=(), dtype=float32)
# 421 tf.Tensor(156.4711, shape=(), dtype=float32)
# 422 tf.Tensor(156.6177, shape=(), dtype=float32)
# 423 tf.Tensor(156.68251, shape=(), dtype=float32)
# 424 tf.Tensor(157.2253, shape=(), dtype=float32)
# 425 tf.Tensor(157.67433, shape=(), dtype=float32)
# 426 tf.Tensor(157.77844, shape=(), dtype=float32)
# 427 tf.Tensor(157.83449, shape=(), dtype=float32)
# 428 tf.Tensor(158.24985, shape=(), dtype=float32)
# 429 tf.Tensor(158.44704, shape=(), dtype=float32)
# 430 tf.Tensor(158.76349, shape=(), dtype=float32)
# 431 tf.Tensor(159.09567, shape=(), dtype=float32)
# 432 tf.Tensor(159.49356, shape=(), dtype=float32)
# 433 tf.Tensor(159.82314, shape=(), dtype=float32)
# 434 tf.Tensor(160.25166, shape=(), dtype=float32)
# 435 tf.Tensor(160.62573, shape=(), dtype=float32)
# 436 tf.Tensor(160.96742, shape=(), dtype=float32)
# 437 tf.Tensor(161.2592, shape=(), dtype=float32)
# 438 tf.Tensor(161.54471, shape=(), dtype=float32)
# 439 tf.Tensor(161.74225, shape=(), dtype=float32)
# 440 tf.Tensor(161.93645, shape=(), dtype=float32)
# 441 tf.Tensor(162.87477, shape=(), dtype=float32)
# 442 tf.Tensor(163.04951, shape=(), dtype=float32)
# 443 tf.Tensor(163.68462, shape=(), dtype=float32)
# 444 tf.Tensor(164.31569, shape=(), dtype=float32)
# 445 tf.Tensor(164.43031, shape=(), dtype=float32)
# 446 tf.Tensor(164.69958, shape=(), dtype=float32)
# 447 tf.Tensor(165.15933, shape=(), dtype=float32)
# 448 tf.Tensor(165.45372, shape=(), dtype=float32)
# 449 tf.Tensor(165.6524, shape=(), dtype=float32)
# 450 tf.Tensor(166.34949, shape=(), dtype=float32)
# 451 tf.Tensor(166.4481, shape=(), dtype=float32)
# 452 tf.Tensor(166.7692, shape=(), dtype=float32)
# 453 tf.Tensor(167.33073, shape=(), dtype=float32)
# 454 tf.Tensor(167.91386, shape=(), dtype=float32)
# 455 tf.Tensor(168.42776, shape=(), dtype=float32)
# 456 tf.Tensor(169.10085, shape=(), dtype=float32)
# 457 tf.Tensor(169.72298, shape=(), dtype=float32)
# 458 tf.Tensor(169.91754, shape=(), dtype=float32)
# 459 tf.Tensor(170.77194, shape=(), dtype=float32)
# 460 tf.Tensor(170.79938, shape=(), dtype=float32)
# 461 tf.Tensor(171.15085, shape=(), dtype=float32)
# 462 tf.Tensor(171.21654, shape=(), dtype=float32)
# 463 tf.Tensor(171.68451, shape=(), dtype=float32)
# 464 tf.Tensor(172.22661, shape=(), dtype=float32)
# 465 tf.Tensor(172.62291, shape=(), dtype=float32)
# 466 tf.Tensor(173.19025, shape=(), dtype=float32)
# 467 tf.Tensor(173.78453, shape=(), dtype=float32)
# 468 tf.Tensor(174.18329, shape=(), dtype=float32)
# 469 tf.Tensor(174.3303, shape=(), dtype=float32)
# 470 tf.Tensor(174.33765, shape=(), dtype=float32)
# 471 tf.Tensor(174.5524, shape=(), dtype=float32)
# 472 tf.Tensor(174.78546, shape=(), dtype=float32)
# 473 tf.Tensor(175.2468, shape=(), dtype=float32)
# 474 tf.Tensor(175.6005, shape=(), dtype=float32)
# 475 tf.Tensor(175.82234, shape=(), dtype=float32)
# 476 tf.Tensor(175.92188, shape=(), dtype=float32)
# 477 tf.Tensor(176.19063, shape=(), dtype=float32)
# 478 tf.Tensor(176.37267, shape=(), dtype=float32)
# 479 tf.Tensor(176.86754, shape=(), dtype=float32)
# 480 tf.Tensor(177.14244, shape=(), dtype=float32)
# 481 tf.Tensor(177.4653, shape=(), dtype=float32)
# 482 tf.Tensor(178.00871, shape=(), dtype=float32)
# 483 tf.Tensor(178.40968, shape=(), dtype=float32)
# 484 tf.Tensor(178.46925, shape=(), dtype=float32)
# 485 tf.Tensor(178.62752, shape=(), dtype=float32)
# 486 tf.Tensor(178.94727, shape=(), dtype=float32)
# 487 tf.Tensor(179.0503, shape=(), dtype=float32)
# 488 tf.Tensor(179.06996, shape=(), dtype=float32)
# 489 tf.Tensor(179.67764, shape=(), dtype=float32)
# 490 tf.Tensor(179.84521, shape=(), dtype=float32)
# 491 tf.Tensor(180.24222, shape=(), dtype=float32)
# 492 tf.Tensor(180.57164, shape=(), dtype=float32)
# 493 tf.Tensor(180.68338, shape=(), dtype=float32)
# 494 tf.Tensor(180.98753, shape=(), dtype=float32)
# 495 tf.Tensor(181.44891, shape=(), dtype=float32)
# 496 tf.Tensor(182.06694, shape=(), dtype=float32)
# 497 tf.Tensor(182.62665, shape=(), dtype=float32)
# 498 tf.Tensor(182.88943, shape=(), dtype=float32)
# 499 tf.Tensor(182.9215, shape=(), dtype=float32)
# 500 tf.Tensor(183.29646, shape=(), dtype=float32)
# 501 tf.Tensor(183.93512, shape=(), dtype=float32)
# 502 tf.Tensor(184.35359, shape=(), dtype=float32)
# 503 tf.Tensor(184.72388, shape=(), dtype=float32)
# 504 tf.Tensor(185.23381, shape=(), dtype=float32)
# 505 tf.Tensor(185.76706, shape=(), dtype=float32)
# 506 tf.Tensor(185.92995, shape=(), dtype=float32)
# 507 tf.Tensor(186.2949, shape=(), dtype=float32)
# 508 tf.Tensor(186.77373, shape=(), dtype=float32)
# 509 tf.Tensor(186.99483, shape=(), dtype=float32)
# 510 tf.Tensor(187.10858, shape=(), dtype=float32)
# 511 tf.Tensor(187.49144, shape=(), dtype=float32)
# 512 tf.Tensor(188.02321, shape=(), dtype=float32)
# 513 tf.Tensor(188.72093, shape=(), dtype=float32)
# 514 tf.Tensor(189.08661, shape=(), dtype=float32)
# 515 tf.Tensor(189.56459, shape=(), dtype=float32)
# 516 tf.Tensor(190.14323, shape=(), dtype=float32)
# 517 tf.Tensor(190.281, shape=(), dtype=float32)
# 518 tf.Tensor(190.51758, shape=(), dtype=float32)
# 519 tf.Tensor(191.22787, shape=(), dtype=float32)
# 520 tf.Tensor(191.54668, shape=(), dtype=float32)
# 521 tf.Tensor(191.58366, shape=(), dtype=float32)
# 522 tf.Tensor(191.67233, shape=(), dtype=float32)
# 523 tf.Tensor(192.04295, shape=(), dtype=float32)
# 524 tf.Tensor(192.16385, shape=(), dtype=float32)
# 525 tf.Tensor(192.43475, shape=(), dtype=float32)
# 526 tf.Tensor(193.05507, shape=(), dtype=float32)
# 527 tf.Tensor(193.57396, shape=(), dtype=float32)
# 528 tf.Tensor(194.20683, shape=(), dtype=float32)
# 529 tf.Tensor(194.80229, shape=(), dtype=float32)
# 530 tf.Tensor(194.8189, shape=(), dtype=float32)
# 531 tf.Tensor(195.47154, shape=(), dtype=float32)
# 532 tf.Tensor(195.69247, shape=(), dtype=float32)
# 533 tf.Tensor(196.16922, shape=(), dtype=float32)
# 534 tf.Tensor(196.92558, shape=(), dtype=float32)
# 535 tf.Tensor(197.5224, shape=(), dtype=float32)
# 536 tf.Tensor(198.30742, shape=(), dtype=float32)
# 537 tf.Tensor(198.41574, shape=(), dtype=float32)
# 538 tf.Tensor(198.41687, shape=(), dtype=float32)
# 539 tf.Tensor(198.43138, shape=(), dtype=float32)
# 540 tf.Tensor(198.75662, shape=(), dtype=float32)
# 541 tf.Tensor(199.27727, shape=(), dtype=float32)
# 542 tf.Tensor(199.65656, shape=(), dtype=float32)
# 543 tf.Tensor(200.20822, shape=(), dtype=float32)
# 544 tf.Tensor(200.31688, shape=(), dtype=float32)
# 545 tf.Tensor(200.37395, shape=(), dtype=float32)
# 546 tf.Tensor(200.51393, shape=(), dtype=float32)
# 547 tf.Tensor(201.14464, shape=(), dtype=float32)
# 548 tf.Tensor(201.52304, shape=(), dtype=float32)
# 549 tf.Tensor(201.84053, shape=(), dtype=float32)
# 550 tf.Tensor(202.16736, shape=(), dtype=float32)
# 551 tf.Tensor(202.63702, shape=(), dtype=float32)
# 552 tf.Tensor(203.29167, shape=(), dtype=float32)
# 553 tf.Tensor(203.7588, shape=(), dtype=float32)
# 554 tf.Tensor(204.30165, shape=(), dtype=float32)
# 555 tf.Tensor(205.22084, shape=(), dtype=float32)
# 556 tf.Tensor(205.63428, shape=(), dtype=float32)
# 557 tf.Tensor(205.6343, shape=(), dtype=float32)
# 558 tf.Tensor(206.2679, shape=(), dtype=float32)
# 559 tf.Tensor(206.66763, shape=(), dtype=float32)
# 560 tf.Tensor(207.01433, shape=(), dtype=float32)
# 561 tf.Tensor(207.21152, shape=(), dtype=float32)
# 562 tf.Tensor(207.43588, shape=(), dtype=float32)
# 563 tf.Tensor(207.83157, shape=(), dtype=float32)
# 564 tf.Tensor(207.98, shape=(), dtype=float32)
# 565 tf.Tensor(208.01324, shape=(), dtype=float32)
# 566 tf.Tensor(208.4661, shape=(), dtype=float32)
# 567 tf.Tensor(209.10855, shape=(), dtype=float32)
# 568 tf.Tensor(209.78479, shape=(), dtype=float32)
# 569 tf.Tensor(210.55884, shape=(), dtype=float32)
# 570 tf.Tensor(211.0669, shape=(), dtype=float32)
# 571 tf.Tensor(211.7756, shape=(), dtype=float32)
# 572 tf.Tensor(212.28786, shape=(), dtype=float32)
# 573 tf.Tensor(212.39027, shape=(), dtype=float32)
# 574 tf.Tensor(212.49203, shape=(), dtype=float32)
# 575 tf.Tensor(212.60567, shape=(), dtype=float32)
# 576 tf.Tensor(213.1148, shape=(), dtype=float32)
# 577 tf.Tensor(213.75319, shape=(), dtype=float32)
# 578 tf.Tensor(214.15758, shape=(), dtype=float32)
# 579 tf.Tensor(214.51352, shape=(), dtype=float32)
# 580 tf.Tensor(214.6792, shape=(), dtype=float32)
# 581 tf.Tensor(214.849, shape=(), dtype=float32)
# 582 tf.Tensor(215.08574, shape=(), dtype=float32)
# 583 tf.Tensor(215.77989, shape=(), dtype=float32)
# 584 tf.Tensor(215.82024, shape=(), dtype=float32)
# 585 tf.Tensor(216.19524, shape=(), dtype=float32)
# 586 tf.Tensor(216.31435, shape=(), dtype=float32)
# 587 tf.Tensor(216.60481, shape=(), dtype=float32)
# 588 tf.Tensor(216.65527, shape=(), dtype=float32)
# 589 tf.Tensor(216.79088, shape=(), dtype=float32)
# 590 tf.Tensor(217.42368, shape=(), dtype=float32)
# 591 tf.Tensor(217.75516, shape=(), dtype=float32)
# 592 tf.Tensor(218.09885, shape=(), dtype=float32)
# 593 tf.Tensor(218.11873, shape=(), dtype=float32)
# 594 tf.Tensor(218.5767, shape=(), dtype=float32)
# 595 tf.Tensor(219.30373, shape=(), dtype=float32)
# 596 tf.Tensor(219.51442, shape=(), dtype=float32)
# 597 tf.Tensor(219.66843, shape=(), dtype=float32)
# 598 tf.Tensor(220.21188, shape=(), dtype=float32)
# 599 tf.Tensor(220.6593, shape=(), dtype=float32)
# 600 tf.Tensor(221.18451, shape=(), dtype=float32)
# 601 tf.Tensor(221.77272, shape=(), dtype=float32)
# 602 tf.Tensor(221.84073, shape=(), dtype=float32)
# 603 tf.Tensor(222.17293, shape=(), dtype=float32)
# 604 tf.Tensor(222.71857, shape=(), dtype=float32)
# 605 tf.Tensor(223.171, shape=(), dtype=float32)
# 606 tf.Tensor(223.5059, shape=(), dtype=float32)
# 607 tf.Tensor(223.88342, shape=(), dtype=float32)
# 608 tf.Tensor(224.34093, shape=(), dtype=float32)
# 609 tf.Tensor(224.53694, shape=(), dtype=float32)
# 610 tf.Tensor(224.673, shape=(), dtype=float32)
# 611 tf.Tensor(225.05005, shape=(), dtype=float32)
# 612 tf.Tensor(225.27309, shape=(), dtype=float32)
# 613 tf.Tensor(225.68425, shape=(), dtype=float32)
# 614 tf.Tensor(225.98715, shape=(), dtype=float32)
# 615 tf.Tensor(226.49998, shape=(), dtype=float32)
# 616 tf.Tensor(227.12059, shape=(), dtype=float32)
# 617 tf.Tensor(227.40265, shape=(), dtype=float32)
# 618 tf.Tensor(228.09595, shape=(), dtype=float32)
# 619 tf.Tensor(228.55428, shape=(), dtype=float32)
# 620 tf.Tensor(228.93436, shape=(), dtype=float32)
# 621 tf.Tensor(229.2935, shape=(), dtype=float32)
# 622 tf.Tensor(229.73642, shape=(), dtype=float32)
# 623 tf.Tensor(230.02872, shape=(), dtype=float32)
# 624 tf.Tensor(230.30559, shape=(), dtype=float32)
# 625 tf.Tensor(230.91241, shape=(), dtype=float32)
# 626 tf.Tensor(231.59033, shape=(), dtype=float32)
# 627 tf.Tensor(231.99199, shape=(), dtype=float32)
# 628 tf.Tensor(232.38731, shape=(), dtype=float32)
# 629 tf.Tensor(232.38747, shape=(), dtype=float32)
# 630 tf.Tensor(233.01001, shape=(), dtype=float32)
# 631 tf.Tensor(233.0107, shape=(), dtype=float32)
# 632 tf.Tensor(233.3703, shape=(), dtype=float32)
# 633 tf.Tensor(233.88663, shape=(), dtype=float32)
# 634 tf.Tensor(234.44157, shape=(), dtype=float32)
# 635 tf.Tensor(234.79355, shape=(), dtype=float32)
# 636 tf.Tensor(235.0816, shape=(), dtype=float32)
# 637 tf.Tensor(235.31638, shape=(), dtype=float32)
# 638 tf.Tensor(235.41862, shape=(), dtype=float32)
# 639 tf.Tensor(236.27074, shape=(), dtype=float32)
# 640 tf.Tensor(236.53966, shape=(), dtype=float32)
# 641 tf.Tensor(236.53975, shape=(), dtype=float32)
# 642 tf.Tensor(236.54007, shape=(), dtype=float32)
# 643 tf.Tensor(236.61577, shape=(), dtype=float32)
# 644 tf.Tensor(237.12299, shape=(), dtype=float32)
# 645 tf.Tensor(237.83493, shape=(), dtype=float32)
# 646 tf.Tensor(238.4793, shape=(), dtype=float32)
# 647 tf.Tensor(238.68433, shape=(), dtype=float32)
# 648 tf.Tensor(239.04349, shape=(), dtype=float32)
# 649 tf.Tensor(239.80539, shape=(), dtype=float32)
# 650 tf.Tensor(240.4799, shape=(), dtype=float32)
# 651 tf.Tensor(241.06105, shape=(), dtype=float32)
# 652 tf.Tensor(241.50166, shape=(), dtype=float32)
# 653 tf.Tensor(241.64418, shape=(), dtype=float32)
# 654 tf.Tensor(242.1031, shape=(), dtype=float32)
# 655 tf.Tensor(242.76097, shape=(), dtype=float32)
# 656 tf.Tensor(242.90407, shape=(), dtype=float32)
# 657 tf.Tensor(243.34293, shape=(), dtype=float32)
# 658 tf.Tensor(244.0196, shape=(), dtype=float32)
# 659 tf.Tensor(244.36832, shape=(), dtype=float32)
# 660 tf.Tensor(244.81909, shape=(), dtype=float32)
# 661 tf.Tensor(245.07182, shape=(), dtype=float32)
# 662 tf.Tensor(245.0796, shape=(), dtype=float32)
# 663 tf.Tensor(245.83595, shape=(), dtype=float32)
# 664 tf.Tensor(246.24675, shape=(), dtype=float32)
# 665 tf.Tensor(246.81142, shape=(), dtype=float32)
# 666 tf.Tensor(247.66815, shape=(), dtype=float32)
# 667 tf.Tensor(247.95976, shape=(), dtype=float32)
# 668 tf.Tensor(248.44878, shape=(), dtype=float32)
# 669 tf.Tensor(248.84012, shape=(), dtype=float32)
# 670 tf.Tensor(249.11523, shape=(), dtype=float32)
# 671 tf.Tensor(249.19861, shape=(), dtype=float32)
# 672 tf.Tensor(249.5461, shape=(), dtype=float32)
# 673 tf.Tensor(249.9806, shape=(), dtype=float32)
# 674 tf.Tensor(250.51125, shape=(), dtype=float32)
# 675 tf.Tensor(250.7058, shape=(), dtype=float32)
# 676 tf.Tensor(251.06973, shape=(), dtype=float32)
# 677 tf.Tensor(251.14032, shape=(), dtype=float32)
# 678 tf.Tensor(251.57571, shape=(), dtype=float32)
# 679 tf.Tensor(251.60744, shape=(), dtype=float32)
# 680 tf.Tensor(251.64662, shape=(), dtype=float32)
# 681 tf.Tensor(252.3464, shape=(), dtype=float32)
# 682 tf.Tensor(252.75748, shape=(), dtype=float32)
# 683 tf.Tensor(252.97403, shape=(), dtype=float32)
# 684 tf.Tensor(253.58014, shape=(), dtype=float32)
# 685 tf.Tensor(253.7972, shape=(), dtype=float32)
# 686 tf.Tensor(254.43231, shape=(), dtype=float32)
# 687 tf.Tensor(254.43512, shape=(), dtype=float32)
# 688 tf.Tensor(254.91652, shape=(), dtype=float32)
# 689 tf.Tensor(255.62749, shape=(), dtype=float32)
# 690 tf.Tensor(256.00006, shape=(), dtype=float32)
# 691 tf.Tensor(256.73547, shape=(), dtype=float32)
# 692 tf.Tensor(256.8021, shape=(), dtype=float32)
# 693 tf.Tensor(257.4799, shape=(), dtype=float32)
# 694 tf.Tensor(258.30106, shape=(), dtype=float32)
# 695 tf.Tensor(258.8427, shape=(), dtype=float32)
# 696 tf.Tensor(259.48947, shape=(), dtype=float32)
# 697 tf.Tensor(259.6693, shape=(), dtype=float32)
# 698 tf.Tensor(260.30655, shape=(), dtype=float32)
# 699 tf.Tensor(260.32297, shape=(), dtype=float32)
# 700 tf.Tensor(261.20126, shape=(), dtype=float32)
# 701 tf.Tensor(261.8968, shape=(), dtype=float32)
# 702 tf.Tensor(262.4441, shape=(), dtype=float32)
# 703 tf.Tensor(262.9855, shape=(), dtype=float32)
# 704 tf.Tensor(263.08112, shape=(), dtype=float32)
# 705 tf.Tensor(263.15073, shape=(), dtype=float32)
# 706 tf.Tensor(263.57056, shape=(), dtype=float32)
# 707 tf.Tensor(264.01273, shape=(), dtype=float32)
# 708 tf.Tensor(264.23322, shape=(), dtype=float32)
# 709 tf.Tensor(264.3766, shape=(), dtype=float32)
# 710 tf.Tensor(264.71768, shape=(), dtype=float32)
# 711 tf.Tensor(265.27914, shape=(), dtype=float32)
# 712 tf.Tensor(265.84732, shape=(), dtype=float32)
# 713 tf.Tensor(266.27646, shape=(), dtype=float32)
# 714 tf.Tensor(266.79114, shape=(), dtype=float32)
# 715 tf.Tensor(267.3228, shape=(), dtype=float32)
# 716 tf.Tensor(267.3881, shape=(), dtype=float32)
# 717 tf.Tensor(267.89624, shape=(), dtype=float32)
# 718 tf.Tensor(268.59064, shape=(), dtype=float32)
# 719 tf.Tensor(268.7594, shape=(), dtype=float32)
# 720 tf.Tensor(269.0635, shape=(), dtype=float32)
# 721 tf.Tensor(269.34192, shape=(), dtype=float32)
# 722 tf.Tensor(269.37863, shape=(), dtype=float32)
# 723 tf.Tensor(269.6734, shape=(), dtype=float32)
# 724 tf.Tensor(269.75833, shape=(), dtype=float32)
# 725 tf.Tensor(269.90094, shape=(), dtype=float32)
# 726 tf.Tensor(270.51718, shape=(), dtype=float32)
# 727 tf.Tensor(270.76883, shape=(), dtype=float32)
# 728 tf.Tensor(270.88998, shape=(), dtype=float32)
# 729 tf.Tensor(271.21732, shape=(), dtype=float32)
# 730 tf.Tensor(271.41998, shape=(), dtype=float32)
# 731 tf.Tensor(271.9256, shape=(), dtype=float32)
# 732 tf.Tensor(272.27863, shape=(), dtype=float32)
# 733 tf.Tensor(272.3124, shape=(), dtype=float32)
# 734 tf.Tensor(272.347, shape=(), dtype=float32)
# 735 tf.Tensor(272.64468, shape=(), dtype=float32)
# 736 tf.Tensor(273.29205, shape=(), dtype=float32)
# 737 tf.Tensor(273.4753, shape=(), dtype=float32)
# 738 tf.Tensor(273.79816, shape=(), dtype=float32)
# 739 tf.Tensor(273.98328, shape=(), dtype=float32)
# 740 tf.Tensor(274.43692, shape=(), dtype=float32)
# 741 tf.Tensor(274.51315, shape=(), dtype=float32)
# 742 tf.Tensor(274.74863, shape=(), dtype=float32)
# 743 tf.Tensor(275.07288, shape=(), dtype=float32)
# 744 tf.Tensor(275.4217, shape=(), dtype=float32)
# 745 tf.Tensor(275.7851, shape=(), dtype=float32)
# 746 tf.Tensor(276.25946, shape=(), dtype=float32)
# 747 tf.Tensor(276.74628, shape=(), dtype=float32)
# 748 tf.Tensor(277.08908, shape=(), dtype=float32)
# 749 tf.Tensor(277.2068, shape=(), dtype=float32)
# 750 tf.Tensor(277.84177, shape=(), dtype=float32)
# 751 tf.Tensor(278.17654, shape=(), dtype=float32)
# 752 tf.Tensor(278.8807, shape=(), dtype=float32)
# 753 tf.Tensor(279.305, shape=(), dtype=float32)
# 754 tf.Tensor(279.38538, shape=(), dtype=float32)
# 755 tf.Tensor(280.03775, shape=(), dtype=float32)
# 756 tf.Tensor(280.6477, shape=(), dtype=float32)
# 757 tf.Tensor(280.7098, shape=(), dtype=float32)
# 758 tf.Tensor(281.21396, shape=(), dtype=float32)
# 759 tf.Tensor(281.94635, shape=(), dtype=float32)
# 760 tf.Tensor(282.1302, shape=(), dtype=float32)
# 761 tf.Tensor(282.6368, shape=(), dtype=float32)
# 762 tf.Tensor(282.70328, shape=(), dtype=float32)
# 763 tf.Tensor(283.03317, shape=(), dtype=float32)
# 764 tf.Tensor(283.43176, shape=(), dtype=float32)
# 765 tf.Tensor(284.17517, shape=(), dtype=float32)
# 766 tf.Tensor(284.42325, shape=(), dtype=float32)
# 767 tf.Tensor(284.65204, shape=(), dtype=float32)
# 768 tf.Tensor(285.30353, shape=(), dtype=float32)
# 769 tf.Tensor(285.3041, shape=(), dtype=float32)
# 770 tf.Tensor(286.04846, shape=(), dtype=float32)
# 771 tf.Tensor(286.43695, shape=(), dtype=float32)
# 772 tf.Tensor(286.95285, shape=(), dtype=float32)
# 773 tf.Tensor(287.2182, shape=(), dtype=float32)
# 774 tf.Tensor(287.5276, shape=(), dtype=float32)
# 775 tf.Tensor(287.6005, shape=(), dtype=float32)
# 776 tf.Tensor(287.9348, shape=(), dtype=float32)
# 777 tf.Tensor(288.25928, shape=(), dtype=float32)
# 778 tf.Tensor(288.5764, shape=(), dtype=float32)
# 779 tf.Tensor(289.28302, shape=(), dtype=float32)
# 780 tf.Tensor(289.6399, shape=(), dtype=float32)
# 781 tf.Tensor(290.08853, shape=(), dtype=float32)
# 782 tf.Tensor(290.5785, shape=(), dtype=float32)
# 783 tf.Tensor(291.34128, shape=(), dtype=float32)
# 784 tf.Tensor(291.61014, shape=(), dtype=float32)
# 785 tf.Tensor(291.79135, shape=(), dtype=float32)
# 786 tf.Tensor(292.2358, shape=(), dtype=float32)
# 787 tf.Tensor(292.55423, shape=(), dtype=float32)
# 788 tf.Tensor(293.15524, shape=(), dtype=float32)
# 789 tf.Tensor(293.46497, shape=(), dtype=float32)
# 790 tf.Tensor(293.51755, shape=(), dtype=float32)
# 791 tf.Tensor(293.6923, shape=(), dtype=float32)
# 792 tf.Tensor(293.8834, shape=(), dtype=float32)
# 793 tf.Tensor(294.52478, shape=(), dtype=float32)
# 794 tf.Tensor(294.9646, shape=(), dtype=float32)
# 795 tf.Tensor(295.09595, shape=(), dtype=float32)
# 796 tf.Tensor(295.40134, shape=(), dtype=float32)
# 797 tf.Tensor(295.5494, shape=(), dtype=float32)
# 798 tf.Tensor(295.90976, shape=(), dtype=float32)
# 799 tf.Tensor(295.9791, shape=(), dtype=float32)
# 800 tf.Tensor(296.34033, shape=(), dtype=float32)
# 801 tf.Tensor(297.19962, shape=(), dtype=float32)
# 802 tf.Tensor(297.38156, shape=(), dtype=float32)
# 803 tf.Tensor(297.8256, shape=(), dtype=float32)
# 804 tf.Tensor(298.06216, shape=(), dtype=float32)
# 805 tf.Tensor(298.40564, shape=(), dtype=float32)
# 806 tf.Tensor(298.50964, shape=(), dtype=float32)
# 807 tf.Tensor(299.01813, shape=(), dtype=float32)
# 808 tf.Tensor(299.66833, shape=(), dtype=float32)
# 809 tf.Tensor(300.2193, shape=(), dtype=float32)
# 810 tf.Tensor(300.76285, shape=(), dtype=float32)
# 811 tf.Tensor(300.79147, shape=(), dtype=float32)
# 812 tf.Tensor(300.8429, shape=(), dtype=float32)
# 813 tf.Tensor(301.50122, shape=(), dtype=float32)
# 814 tf.Tensor(301.55237, shape=(), dtype=float32)
# 815 tf.Tensor(302.24344, shape=(), dtype=float32)
# 816 tf.Tensor(302.42078, shape=(), dtype=float32)
# 817 tf.Tensor(302.4208, shape=(), dtype=float32)
# 818 tf.Tensor(302.73737, shape=(), dtype=float32)
# 819 tf.Tensor(303.1534, shape=(), dtype=float32)
# 820 tf.Tensor(303.7061, shape=(), dtype=float32)
# 821 tf.Tensor(303.8818, shape=(), dtype=float32)
# 822 tf.Tensor(303.89206, shape=(), dtype=float32)
# 823 tf.Tensor(304.3975, shape=(), dtype=float32)
# 824 tf.Tensor(304.5841, shape=(), dtype=float32)
# 825 tf.Tensor(305.2017, shape=(), dtype=float32)
# 826 tf.Tensor(305.3061, shape=(), dtype=float32)
# 827 tf.Tensor(305.85495, shape=(), dtype=float32)
# 828 tf.Tensor(306.31387, shape=(), dtype=float32)
# 829 tf.Tensor(306.49152, shape=(), dtype=float32)
# 830 tf.Tensor(306.83374, shape=(), dtype=float32)
# 831 tf.Tensor(307.50674, shape=(), dtype=float32)
# 832 tf.Tensor(308.23102, shape=(), dtype=float32)
# 833 tf.Tensor(309.0068, shape=(), dtype=float32)
# 834 tf.Tensor(309.53812, shape=(), dtype=float32)
# 835 tf.Tensor(309.88443, shape=(), dtype=float32)
# 836 tf.Tensor(310.0428, shape=(), dtype=float32)
# 837 tf.Tensor(310.6078, shape=(), dtype=float32)
# 838 tf.Tensor(311.17792, shape=(), dtype=float32)
# 839 tf.Tensor(311.794, shape=(), dtype=float32)
# 840 tf.Tensor(312.023, shape=(), dtype=float32)
# 841 tf.Tensor(312.18283, shape=(), dtype=float32)
# 842 tf.Tensor(312.18948, shape=(), dtype=float32)
# 843 tf.Tensor(313.03143, shape=(), dtype=float32)
# 844 tf.Tensor(313.6466, shape=(), dtype=float32)
# 845 tf.Tensor(314.09256, shape=(), dtype=float32)
# 846 tf.Tensor(314.3331, shape=(), dtype=float32)
# 847 tf.Tensor(314.8913, shape=(), dtype=float32)
# 848 tf.Tensor(315.02774, shape=(), dtype=float32)
# 849 tf.Tensor(315.02786, shape=(), dtype=float32)
# 850 tf.Tensor(315.1477, shape=(), dtype=float32)
# 851 tf.Tensor(315.53564, shape=(), dtype=float32)
# 852 tf.Tensor(315.73358, shape=(), dtype=float32)
# 853 tf.Tensor(316.07874, shape=(), dtype=float32)
# 854 tf.Tensor(316.23203, shape=(), dtype=float32)
# 855 tf.Tensor(316.7783, shape=(), dtype=float32)
# 856 tf.Tensor(317.20514, shape=(), dtype=float32)
# 857 tf.Tensor(317.87704, shape=(), dtype=float32)
# 858 tf.Tensor(318.2611, shape=(), dtype=float32)
# 859 tf.Tensor(318.6588, shape=(), dtype=float32)
# 860 tf.Tensor(319.04807, shape=(), dtype=float32)
# 861 tf.Tensor(319.52173, shape=(), dtype=float32)
# 862 tf.Tensor(319.53265, shape=(), dtype=float32)
# 863 tf.Tensor(319.53543, shape=(), dtype=float32)
# 864 tf.Tensor(320.1732, shape=(), dtype=float32)
# 865 tf.Tensor(320.7105, shape=(), dtype=float32)
# 866 tf.Tensor(321.2573, shape=(), dtype=float32)
# 867 tf.Tensor(321.6366, shape=(), dtype=float32)
# 868 tf.Tensor(322.20853, shape=(), dtype=float32)
# 869 tf.Tensor(322.41745, shape=(), dtype=float32)
# 870 tf.Tensor(322.6132, shape=(), dtype=float32)
# 871 tf.Tensor(323.41797, shape=(), dtype=float32)
# 872 tf.Tensor(323.76328, shape=(), dtype=float32)
# 873 tf.Tensor(324.11795, shape=(), dtype=float32)
# 874 tf.Tensor(324.78644, shape=(), dtype=float32)
# 875 tf.Tensor(325.1315, shape=(), dtype=float32)
# 876 tf.Tensor(325.47903, shape=(), dtype=float32)
# 877 tf.Tensor(325.73215, shape=(), dtype=float32)
# 878 tf.Tensor(326.065, shape=(), dtype=float32)
# 879 tf.Tensor(326.5595, shape=(), dtype=float32)
# 880 tf.Tensor(327.0699, shape=(), dtype=float32)
# 881 tf.Tensor(327.13983, shape=(), dtype=float32)
# 882 tf.Tensor(327.42883, shape=(), dtype=float32)
# 883 tf.Tensor(327.785, shape=(), dtype=float32)
# 884 tf.Tensor(328.08997, shape=(), dtype=float32)
# 885 tf.Tensor(328.3608, shape=(), dtype=float32)
# 886 tf.Tensor(328.74866, shape=(), dtype=float32)
# 887 tf.Tensor(329.19583, shape=(), dtype=float32)
# 888 tf.Tensor(329.68912, shape=(), dtype=float32)
# 889 tf.Tensor(329.69, shape=(), dtype=float32)
# 890 tf.Tensor(330.02783, shape=(), dtype=float32)
# 891 tf.Tensor(330.66763, shape=(), dtype=float32)
# 892 tf.Tensor(330.7176, shape=(), dtype=float32)
# 893 tf.Tensor(331.0601, shape=(), dtype=float32)
# 894 tf.Tensor(331.29715, shape=(), dtype=float32)
# 895 tf.Tensor(332.02197, shape=(), dtype=float32)
# 896 tf.Tensor(332.5002, shape=(), dtype=float32)
# 897 tf.Tensor(332.66843, shape=(), dtype=float32)
# 898 tf.Tensor(333.0447, shape=(), dtype=float32)
# 899 tf.Tensor(333.7975, shape=(), dtype=float32)
# 900 tf.Tensor(333.8545, shape=(), dtype=float32)
# 901 tf.Tensor(334.2369, shape=(), dtype=float32)
# 902 tf.Tensor(334.49048, shape=(), dtype=float32)
# 903 tf.Tensor(334.60214, shape=(), dtype=float32)
# 904 tf.Tensor(335.21936, shape=(), dtype=float32)
# 905 tf.Tensor(335.57654, shape=(), dtype=float32)
# 906 tf.Tensor(336.1143, shape=(), dtype=float32)
# 907 tf.Tensor(336.21472, shape=(), dtype=float32)
# 908 tf.Tensor(336.87204, shape=(), dtype=float32)
# 909 tf.Tensor(337.49347, shape=(), dtype=float32)
# 910 tf.Tensor(337.94315, shape=(), dtype=float32)
# 911 tf.Tensor(338.36987, shape=(), dtype=float32)
# 912 tf.Tensor(338.94794, shape=(), dtype=float32)
# 913 tf.Tensor(339.02197, shape=(), dtype=float32)
# 914 tf.Tensor(339.3176, shape=(), dtype=float32)
# 915 tf.Tensor(339.33557, shape=(), dtype=float32)
# 916 tf.Tensor(339.5573, shape=(), dtype=float32)
# 917 tf.Tensor(340.24622, shape=(), dtype=float32)
# 918 tf.Tensor(340.6536, shape=(), dtype=float32)
# 919 tf.Tensor(340.84775, shape=(), dtype=float32)
# 920 tf.Tensor(341.02908, shape=(), dtype=float32)
# 921 tf.Tensor(341.0298, shape=(), dtype=float32)
# 922 tf.Tensor(341.42294, shape=(), dtype=float32)
# 923 tf.Tensor(341.55347, shape=(), dtype=float32)
# 924 tf.Tensor(342.43918, shape=(), dtype=float32)
# 925 tf.Tensor(342.46906, shape=(), dtype=float32)
# 926 tf.Tensor(342.99673, shape=(), dtype=float32)
# 927 tf.Tensor(343.46182, shape=(), dtype=float32)
# 928 tf.Tensor(343.47864, shape=(), dtype=float32)
# 929 tf.Tensor(344.28833, shape=(), dtype=float32)
# 930 tf.Tensor(344.30844, shape=(), dtype=float32)
# 931 tf.Tensor(344.7823, shape=(), dtype=float32)
# 932 tf.Tensor(345.4336, shape=(), dtype=float32)
# 933 tf.Tensor(345.872, shape=(), dtype=float32)
# 934 tf.Tensor(346.03836, shape=(), dtype=float32)
# 935 tf.Tensor(346.47964, shape=(), dtype=float32)
# 936 tf.Tensor(346.5502, shape=(), dtype=float32)
# 937 tf.Tensor(346.95465, shape=(), dtype=float32)
# 938 tf.Tensor(347.11838, shape=(), dtype=float32)
# 939 tf.Tensor(347.64432, shape=(), dtype=float32)
# 940 tf.Tensor(348.06763, shape=(), dtype=float32)
# 941 tf.Tensor(348.55344, shape=(), dtype=float32)
# 942 tf.Tensor(348.97186, shape=(), dtype=float32)
# 943 tf.Tensor(348.9761, shape=(), dtype=float32)
# 944 tf.Tensor(349.20343, shape=(), dtype=float32)
# 945 tf.Tensor(349.47635, shape=(), dtype=float32)
# 946 tf.Tensor(349.76334, shape=(), dtype=float32)
# 947 tf.Tensor(349.9934, shape=(), dtype=float32)
# 948 tf.Tensor(350.3381, shape=(), dtype=float32)
# 949 tf.Tensor(350.43857, shape=(), dtype=float32)
# 950 tf.Tensor(350.6183, shape=(), dtype=float32)
# 951 tf.Tensor(351.2158, shape=(), dtype=float32)
# 952 tf.Tensor(351.32565, shape=(), dtype=float32)
# 953 tf.Tensor(351.8513, shape=(), dtype=float32)
# 954 tf.Tensor(352.60272, shape=(), dtype=float32)
# 955 tf.Tensor(352.9191, shape=(), dtype=float32)
# 956 tf.Tensor(353.14017, shape=(), dtype=float32)
# 957 tf.Tensor(353.19904, shape=(), dtype=float32)
# 958 tf.Tensor(353.29218, shape=(), dtype=float32)
# 959 tf.Tensor(353.46185, shape=(), dtype=float32)
# 960 tf.Tensor(354.0527, shape=(), dtype=float32)
# 961 tf.Tensor(354.18362, shape=(), dtype=float32)
# 962 tf.Tensor(354.8337, shape=(), dtype=float32)
# 963 tf.Tensor(355.46777, shape=(), dtype=float32)
# 964 tf.Tensor(356.06827, shape=(), dtype=float32)
# 965 tf.Tensor(356.23087, shape=(), dtype=float32)
# 966 tf.Tensor(356.5947, shape=(), dtype=float32)
# 967 tf.Tensor(356.92114, shape=(), dtype=float32)
# ...
# 1676 tf.Tensor(628.8356, shape=(), dtype=float32)
# 1677 tf.Tensor(628.9532, shape=(), dtype=float32)
# 1678 tf.Tensor(629.2105, shape=(), dtype=float32)
# 1679 tf.Tensor(629.35974, shape=(), dtype=float32)
# 1680 tf.Tensor(629.3761, shape=(), dtype=float32)
# 1681 tf.Tensor(629.7936, shape=(), dtype=float32)
# 1682 tf.Tensor(630.31476, shape=(), dtype=float32)
# 1683 tf.Tensor(631.0556, shape=(), dtype=float32)
# 1684 tf.Tensor(631.50494, shape=(), dtype=float32)
# 1685 tf.Tensor(631.9751, shape=(), dtype=float32)
# 1686 tf.Tensor(632.68567, shape=(), dtype=float32)
# 1687 tf.Tensor(632.68616, shape=(), dtype=float32)
# 1688 tf.Tensor(633.11487, shape=(), dtype=float32)
# 1689 tf.Tensor(633.4982, shape=(), dtype=float32)
# 1690 tf.Tensor(634.0664, shape=(), dtype=float32)
# 1691 tf.Tensor(634.5045, shape=(), dtype=float32)
# 1692 tf.Tensor(634.8278, shape=(), dtype=float32)
# 1693 tf.Tensor(635.2885, shape=(), dtype=float32)
# 1694 tf.Tensor(636.01624, shape=(), dtype=float32)
# 1695 tf.Tensor(636.5158, shape=(), dtype=float32)
# 1696 tf.Tensor(636.7402, shape=(), dtype=float32)
# 1697 tf.Tensor(637.2109, shape=(), dtype=float32)
# 1698 tf.Tensor(637.50525, shape=(), dtype=float32)
# 1699 tf.Tensor(637.9521, shape=(), dtype=float32)
# 1700 tf.Tensor(638.23376, shape=(), dtype=float32)
# 1701 tf.Tensor(638.7028, shape=(), dtype=float32)
# 1702 tf.Tensor(639.2967, shape=(), dtype=float32)
# 1703 tf.Tensor(639.3353, shape=(), dtype=float32)
# 1704 tf.Tensor(639.8064, shape=(), dtype=float32)
# 1705 tf.Tensor(640.264, shape=(), dtype=float32)
# 1706 tf.Tensor(640.49646, shape=(), dtype=float32)
# 1707 tf.Tensor(640.8139, shape=(), dtype=float32)
# 1708 tf.Tensor(641.2868, shape=(), dtype=float32)
# 1709 tf.Tensor(641.7292, shape=(), dtype=float32)
# 1710 tf.Tensor(642.26, shape=(), dtype=float32)
# 1711 tf.Tensor(643.15753, shape=(), dtype=float32)
# 1712 tf.Tensor(643.2835, shape=(), dtype=float32)
# 1713 tf.Tensor(643.30646, shape=(), dtype=float32)
# 1714 tf.Tensor(643.8726, shape=(), dtype=float32)
# 1715 tf.Tensor(643.9089, shape=(), dtype=float32)
# 1716 tf.Tensor(644.25684, shape=(), dtype=float32)
# 1717 tf.Tensor(645.0602, shape=(), dtype=float32)
# 1718 tf.Tensor(645.1823, shape=(), dtype=float32)
# 1719 tf.Tensor(645.4215, shape=(), dtype=float32)
# 1720 tf.Tensor(646.06976, shape=(), dtype=float32)
# 1721 tf.Tensor(646.68005, shape=(), dtype=float32)
# 1722 tf.Tensor(646.8585, shape=(), dtype=float32)
# 1723 tf.Tensor(647.5308, shape=(), dtype=float32)
# 1724 tf.Tensor(647.7111, shape=(), dtype=float32)
# 1725 tf.Tensor(647.9866, shape=(), dtype=float32)
# 1726 tf.Tensor(648.27, shape=(), dtype=float32)
# 1727 tf.Tensor(648.55347, shape=(), dtype=float32)
# 1728 tf.Tensor(648.92365, shape=(), dtype=float32)
# 1729 tf.Tensor(649.5146, shape=(), dtype=float32)
# 1730 tf.Tensor(650.0493, shape=(), dtype=float32)
# 1731 tf.Tensor(650.1424, shape=(), dtype=float32)
# 1732 tf.Tensor(650.3777, shape=(), dtype=float32)
# 1733 tf.Tensor(650.6414, shape=(), dtype=float32)
# 1734 tf.Tensor(651.1547, shape=(), dtype=float32)
# 1735 tf.Tensor(651.7065, shape=(), dtype=float32)
# 1736 tf.Tensor(652.2513, shape=(), dtype=float32)
# 1737 tf.Tensor(652.4891, shape=(), dtype=float32)
# 1738 tf.Tensor(652.86774, shape=(), dtype=float32)
# 1739 tf.Tensor(653.1373, shape=(), dtype=float32)
# 1740 tf.Tensor(653.64935, shape=(), dtype=float32)
# 1741 tf.Tensor(654.4072, shape=(), dtype=float32)
# 1742 tf.Tensor(654.7223, shape=(), dtype=float32)
# 1743 tf.Tensor(654.89075, shape=(), dtype=float32)
# 1744 tf.Tensor(655.1582, shape=(), dtype=float32)
# 1745 tf.Tensor(655.3385, shape=(), dtype=float32)
# 1746 tf.Tensor(655.5805, shape=(), dtype=float32)
# 1747 tf.Tensor(656.18195, shape=(), dtype=float32)
# 1748 tf.Tensor(657.0011, shape=(), dtype=float32)
# 1749 tf.Tensor(657.45557, shape=(), dtype=float32)
# 1750 tf.Tensor(657.9393, shape=(), dtype=float32)
# 1751 tf.Tensor(658.06177, shape=(), dtype=float32)
# 1752 tf.Tensor(658.47034, shape=(), dtype=float32)
# 1753 tf.Tensor(659.15936, shape=(), dtype=float32)
# 1754 tf.Tensor(659.3359, shape=(), dtype=float32)
# 1755 tf.Tensor(659.4261, shape=(), dtype=float32)
# 1756 tf.Tensor(659.92596, shape=(), dtype=float32)
# 1757 tf.Tensor(660.09216, shape=(), dtype=float32)
# 1758 tf.Tensor(660.2538, shape=(), dtype=float32)
# 1759 tf.Tensor(660.67377, shape=(), dtype=float32)
# 1760 tf.Tensor(661.3741, shape=(), dtype=float32)
# 1761 tf.Tensor(661.5689, shape=(), dtype=float32)
# 1762 tf.Tensor(661.7849, shape=(), dtype=float32)
# 1763 tf.Tensor(662.40857, shape=(), dtype=float32)
# 1764 tf.Tensor(662.7878, shape=(), dtype=float32)
# 1765 tf.Tensor(663.4461, shape=(), dtype=float32)
# 1766 tf.Tensor(663.70264, shape=(), dtype=float32)
# 1767 tf.Tensor(663.90857, shape=(), dtype=float32)
# 1768 tf.Tensor(664.5434, shape=(), dtype=float32)
# 1769 tf.Tensor(665.29315, shape=(), dtype=float32)
# 1770 tf.Tensor(665.9041, shape=(), dtype=float32)
# 1771 tf.Tensor(666.2139, shape=(), dtype=float32)
# 1772 tf.Tensor(666.92847, shape=(), dtype=float32)
# 1773 tf.Tensor(667.57916, shape=(), dtype=float32)
# 1774 tf.Tensor(667.7369, shape=(), dtype=float32)
# 1775 tf.Tensor(667.9899, shape=(), dtype=float32)
# 1776 tf.Tensor(668.3759, shape=(), dtype=float32)
# 1777 tf.Tensor(668.8116, shape=(), dtype=float32)
# 1778 tf.Tensor(668.8506, shape=(), dtype=float32)
# 1779 tf.Tensor(669.0455, shape=(), dtype=float32)
# 1780 tf.Tensor(669.8167, shape=(), dtype=float32)
# 1781 tf.Tensor(670.2064, shape=(), dtype=float32)
# 1782 tf.Tensor(670.706, shape=(), dtype=float32)
# 1783 tf.Tensor(671.3241, shape=(), dtype=float32)
# 1784 tf.Tensor(671.8998, shape=(), dtype=float32)
# 1785 tf.Tensor(671.94727, shape=(), dtype=float32)
# 1786 tf.Tensor(672.12897, shape=(), dtype=float32)
# 1787 tf.Tensor(672.2151, shape=(), dtype=float32)
# 1788 tf.Tensor(672.8089, shape=(), dtype=float32)
# 1789 tf.Tensor(673.31525, shape=(), dtype=float32)
# 1790 tf.Tensor(673.4291, shape=(), dtype=float32)
# 1791 tf.Tensor(673.89886, shape=(), dtype=float32)
# 1792 tf.Tensor(674.1583, shape=(), dtype=float32)
# 1793 tf.Tensor(674.5274, shape=(), dtype=float32)
# 1794 tf.Tensor(675.1724, shape=(), dtype=float32)
# 1795 tf.Tensor(675.7585, shape=(), dtype=float32)
# 1796 tf.Tensor(676.28076, shape=(), dtype=float32)
# 1797 tf.Tensor(676.5389, shape=(), dtype=float32)
# 1798 tf.Tensor(676.7796, shape=(), dtype=float32)
# 1799 tf.Tensor(677.1986, shape=(), dtype=float32)
# 1800 tf.Tensor(677.4708, shape=(), dtype=float32)
# 1801 tf.Tensor(677.9585, shape=(), dtype=float32)
# 1802 tf.Tensor(678.22205, shape=(), dtype=float32)
# 1803 tf.Tensor(678.76904, shape=(), dtype=float32)
# 1804 tf.Tensor(678.95013, shape=(), dtype=float32)
# 1805 tf.Tensor(679.16315, shape=(), dtype=float32)
# 1806 tf.Tensor(679.79126, shape=(), dtype=float32)
# 1807 tf.Tensor(680.08154, shape=(), dtype=float32)
# 1808 tf.Tensor(680.17847, shape=(), dtype=float32)
# 1809 tf.Tensor(680.59906, shape=(), dtype=float32)
# 1810 tf.Tensor(680.6958, shape=(), dtype=float32)
# 1811 tf.Tensor(680.7951, shape=(), dtype=float32)
# 1812 tf.Tensor(680.9265, shape=(), dtype=float32)
# 1813 tf.Tensor(681.37354, shape=(), dtype=float32)
# 1814 tf.Tensor(681.37384, shape=(), dtype=float32)
# 1815 tf.Tensor(681.9058, shape=(), dtype=float32)
# 1816 tf.Tensor(682.1643, shape=(), dtype=float32)
# 1817 tf.Tensor(682.7718, shape=(), dtype=float32)
# 1818 tf.Tensor(683.3798, shape=(), dtype=float32)
# 1819 tf.Tensor(684.00507, shape=(), dtype=float32)
# 1820 tf.Tensor(684.07275, shape=(), dtype=float32)
# 1821 tf.Tensor(684.5933, shape=(), dtype=float32)
# 1822 tf.Tensor(684.9994, shape=(), dtype=float32)
# 1823 tf.Tensor(685.3883, shape=(), dtype=float32)
# 1824 tf.Tensor(685.7585, shape=(), dtype=float32)
# 1825 tf.Tensor(686.16077, shape=(), dtype=float32)
# 1826 tf.Tensor(686.73486, shape=(), dtype=float32)
# 1827 tf.Tensor(686.86523, shape=(), dtype=float32)
# 1828 tf.Tensor(686.94336, shape=(), dtype=float32)
# 1829 tf.Tensor(687.90283, shape=(), dtype=float32)
# 1830 tf.Tensor(688.1051, shape=(), dtype=float32)
# 1831 tf.Tensor(688.3752, shape=(), dtype=float32)
# 1832 tf.Tensor(688.79297, shape=(), dtype=float32)
# 1833 tf.Tensor(689.1586, shape=(), dtype=float32)
# 1834 tf.Tensor(689.34283, shape=(), dtype=float32)
# 1835 tf.Tensor(689.9984, shape=(), dtype=float32)
# 1836 tf.Tensor(690.07, shape=(), dtype=float32)
# 1837 tf.Tensor(690.428, shape=(), dtype=float32)
# 1838 tf.Tensor(690.63196, shape=(), dtype=float32)
# 1839 tf.Tensor(691.179, shape=(), dtype=float32)
# 1840 tf.Tensor(691.74414, shape=(), dtype=float32)
# 1841 tf.Tensor(691.7596, shape=(), dtype=float32)
# 1842 tf.Tensor(691.9477, shape=(), dtype=float32)
# 1843 tf.Tensor(692.40076, shape=(), dtype=float32)
# 1844 tf.Tensor(693.0503, shape=(), dtype=float32)
# 1845 tf.Tensor(693.7912, shape=(), dtype=float32)
# 1846 tf.Tensor(694.3511, shape=(), dtype=float32)
# 1847 tf.Tensor(694.77185, shape=(), dtype=float32)
# 1848 tf.Tensor(694.8643, shape=(), dtype=float32)
# 1849 tf.Tensor(694.88116, shape=(), dtype=float32)
# 1850 tf.Tensor(695.4252, shape=(), dtype=float32)
# 1851 tf.Tensor(695.73706, shape=(), dtype=float32)
# 1852 tf.Tensor(696.1355, shape=(), dtype=float32)
# 1853 tf.Tensor(696.3053, shape=(), dtype=float32)
# 1854 tf.Tensor(696.911, shape=(), dtype=float32)
# 1855 tf.Tensor(697.51135, shape=(), dtype=float32)
# 1856 tf.Tensor(697.935, shape=(), dtype=float32)
# 1857 tf.Tensor(697.9745, shape=(), dtype=float32)
# 1858 tf.Tensor(698.41156, shape=(), dtype=float32)
# 1859 tf.Tensor(699.0944, shape=(), dtype=float32)
# 1860 tf.Tensor(699.2232, shape=(), dtype=float32)
# 1861 tf.Tensor(699.8082, shape=(), dtype=float32)
# 1862 tf.Tensor(700.0517, shape=(), dtype=float32)
# 1863 tf.Tensor(700.4307, shape=(), dtype=float32)
# 1864 tf.Tensor(701.1141, shape=(), dtype=float32)
# 1865 tf.Tensor(701.5743, shape=(), dtype=float32)
# 1866 tf.Tensor(701.58765, shape=(), dtype=float32)
# 1867 tf.Tensor(701.9839, shape=(), dtype=float32)
# 1868 tf.Tensor(702.29297, shape=(), dtype=float32)
# 1869 tf.Tensor(702.6988, shape=(), dtype=float32)
# 1870 tf.Tensor(702.77765, shape=(), dtype=float32)
# 1871 tf.Tensor(702.9719, shape=(), dtype=float32)
# 1872 tf.Tensor(703.05597, shape=(), dtype=float32)
# 1873 tf.Tensor(703.57227, shape=(), dtype=float32)
# 1874 tf.Tensor(704.09454, shape=(), dtype=float32)
# 1875 tf.Tensor(704.38495, shape=(), dtype=float32)
# 1876 tf.Tensor(704.9032, shape=(), dtype=float32)
# 1877 tf.Tensor(705.00854, shape=(), dtype=float32)
# 1878 tf.Tensor(705.3818, shape=(), dtype=float32)
# 1879 tf.Tensor(705.9647, shape=(), dtype=float32)
# 1880 tf.Tensor(706.5211, shape=(), dtype=float32)
# 1881 tf.Tensor(707.3078, shape=(), dtype=float32)
# 1882 tf.Tensor(707.777, shape=(), dtype=float32)
# 1883 tf.Tensor(707.94275, shape=(), dtype=float32)
# 1884 tf.Tensor(708.4033, shape=(), dtype=float32)
# 1885 tf.Tensor(708.87085, shape=(), dtype=float32)
# 1886 tf.Tensor(709.4617, shape=(), dtype=float32)
# 1887 tf.Tensor(709.9097, shape=(), dtype=float32)
# 1888 tf.Tensor(710.07715, shape=(), dtype=float32)
# 1889 tf.Tensor(710.56573, shape=(), dtype=float32)
# 1890 tf.Tensor(711.2767, shape=(), dtype=float32)
# 1891 tf.Tensor(711.95715, shape=(), dtype=float32)
# 1892 tf.Tensor(712.4558, shape=(), dtype=float32)
# 1893 tf.Tensor(713.01624, shape=(), dtype=float32)
# 1894 tf.Tensor(713.15234, shape=(), dtype=float32)
# 1895 tf.Tensor(713.5143, shape=(), dtype=float32)
# 1896 tf.Tensor(714.10333, shape=(), dtype=float32)
# 1897 tf.Tensor(714.3517, shape=(), dtype=float32)
# 1898 tf.Tensor(714.5359, shape=(), dtype=float32)
# 1899 tf.Tensor(714.7638, shape=(), dtype=float32)
# 1900 tf.Tensor(715.267, shape=(), dtype=float32)
# 1901 tf.Tensor(715.5681, shape=(), dtype=float32)
# 1902 tf.Tensor(715.6291, shape=(), dtype=float32)
# 1903 tf.Tensor(715.9784, shape=(), dtype=float32)
# 1904 tf.Tensor(716.7312, shape=(), dtype=float32)
# 1905 tf.Tensor(716.8979, shape=(), dtype=float32)
# 1906 tf.Tensor(717.42035, shape=(), dtype=float32)
# 1907 tf.Tensor(718.06226, shape=(), dtype=float32)
# 1908 tf.Tensor(718.43677, shape=(), dtype=float32)
# 1909 tf.Tensor(718.6571, shape=(), dtype=float32)
# 1910 tf.Tensor(718.96356, shape=(), dtype=float32)
# 1911 tf.Tensor(719.08844, shape=(), dtype=float32)
# 1912 tf.Tensor(719.4329, shape=(), dtype=float32)
# 1913 tf.Tensor(719.9203, shape=(), dtype=float32)
# 1914 tf.Tensor(720.5522, shape=(), dtype=float32)
# 1915 tf.Tensor(721.2735, shape=(), dtype=float32)
# 1916 tf.Tensor(721.4227, shape=(), dtype=float32)
# 1917 tf.Tensor(721.4248, shape=(), dtype=float32)
# 1918 tf.Tensor(721.8346, shape=(), dtype=float32)
# 1919 tf.Tensor(721.83466, shape=(), dtype=float32)
# 1920 tf.Tensor(722.1461, shape=(), dtype=float32)
# 1921 tf.Tensor(722.6266, shape=(), dtype=float32)
# 1922 tf.Tensor(722.68115, shape=(), dtype=float32)
# 1923 tf.Tensor(723.06506, shape=(), dtype=float32)
# 1924 tf.Tensor(723.6749, shape=(), dtype=float32)
# 1925 tf.Tensor(724.15436, shape=(), dtype=float32)
# 1926 tf.Tensor(724.56995, shape=(), dtype=float32)
# 1927 tf.Tensor(724.88446, shape=(), dtype=float32)
# 1928 tf.Tensor(725.34644, shape=(), dtype=float32)
# 1929 tf.Tensor(725.5497, shape=(), dtype=float32)
# 1930 tf.Tensor(725.6584, shape=(), dtype=float32)
# 1931 tf.Tensor(726.46735, shape=(), dtype=float32)
# 1932 tf.Tensor(726.7877, shape=(), dtype=float32)
# 1933 tf.Tensor(727.2134, shape=(), dtype=float32)
# 1934 tf.Tensor(727.58997, shape=(), dtype=float32)
# 1935 tf.Tensor(728.08875, shape=(), dtype=float32)
# 1936 tf.Tensor(728.0891, shape=(), dtype=float32)
# 1937 tf.Tensor(728.47687, shape=(), dtype=float32)
# 1938 tf.Tensor(728.83307, shape=(), dtype=float32)
# 1939 tf.Tensor(729.3766, shape=(), dtype=float32)
# 1940 tf.Tensor(730.07275, shape=(), dtype=float32)
# 1941 tf.Tensor(730.64606, shape=(), dtype=float32)
# 1942 tf.Tensor(730.81757, shape=(), dtype=float32)
# 1943 tf.Tensor(730.84106, shape=(), dtype=float32)
# 1944 tf.Tensor(731.5115, shape=(), dtype=float32)
# 1945 tf.Tensor(731.74347, shape=(), dtype=float32)
# 1946 tf.Tensor(731.8741, shape=(), dtype=float32)
# 1947 tf.Tensor(731.96893, shape=(), dtype=float32)
# 1948 tf.Tensor(732.1419, shape=(), dtype=float32)
# 1949 tf.Tensor(732.8918, shape=(), dtype=float32)
# 1950 tf.Tensor(733.285, shape=(), dtype=float32)
# 1951 tf.Tensor(733.9347, shape=(), dtype=float32)
# 1952 tf.Tensor(734.6701, shape=(), dtype=float32)
# 1953 tf.Tensor(734.82513, shape=(), dtype=float32)
# 1954 tf.Tensor(735.1541, shape=(), dtype=float32)
# 1955 tf.Tensor(735.5313, shape=(), dtype=float32)
# 1956 tf.Tensor(736.0993, shape=(), dtype=float32)
# 1957 tf.Tensor(736.4527, shape=(), dtype=float32)
# 1958 tf.Tensor(736.64264, shape=(), dtype=float32)
# 1959 tf.Tensor(736.86957, shape=(), dtype=float32)
# 1960 tf.Tensor(737.32306, shape=(), dtype=float32)
# 1961 tf.Tensor(737.776, shape=(), dtype=float32)
# 1962 tf.Tensor(738.12476, shape=(), dtype=float32)
# 1963 tf.Tensor(738.5328, shape=(), dtype=float32)
# 1964 tf.Tensor(738.73517, shape=(), dtype=float32)
# 1965 tf.Tensor(739.189, shape=(), dtype=float32)
# 1966 tf.Tensor(739.5727, shape=(), dtype=float32)
# 1967 tf.Tensor(740.4356, shape=(), dtype=float32)
# 1968 tf.Tensor(741.101, shape=(), dtype=float32)
# 1969 tf.Tensor(741.61224, shape=(), dtype=float32)
# 1970 tf.Tensor(741.8986, shape=(), dtype=float32)
# 1971 tf.Tensor(742.0004, shape=(), dtype=float32)
# 1972 tf.Tensor(742.2578, shape=(), dtype=float32)
# 1973 tf.Tensor(742.7917, shape=(), dtype=float32)
# 1974 tf.Tensor(743.30963, shape=(), dtype=float32)
# 1975 tf.Tensor(743.8616, shape=(), dtype=float32)
# 1976 tf.Tensor(744.07776, shape=(), dtype=float32)
# 1977 tf.Tensor(744.38837, shape=(), dtype=float32)
# 1978 tf.Tensor(745.0915, shape=(), dtype=float32)
# 1979 tf.Tensor(745.5722, shape=(), dtype=float32)
# 1980 tf.Tensor(745.9292, shape=(), dtype=float32)
# 1981 tf.Tensor(746.4973, shape=(), dtype=float32)
# 1982 tf.Tensor(746.64935, shape=(), dtype=float32)
# 1983 tf.Tensor(747.32153, shape=(), dtype=float32)
# 1984 tf.Tensor(747.6369, shape=(), dtype=float32)
# 1985 tf.Tensor(748.06445, shape=(), dtype=float32)
# 1986 tf.Tensor(748.2104, shape=(), dtype=float32)
# 1987 tf.Tensor(748.49927, shape=(), dtype=float32)
# 1988 tf.Tensor(749.02515, shape=(), dtype=float32)
# 1989 tf.Tensor(749.11835, shape=(), dtype=float32)
# *****************************************************************************************************************
# <tf.Tensor: shape=(), dtype=float32, numpy=0.3764414>

# %%
# model2 = main_model2(shape,no_classes)
# model2=tf.keras.models.load_model(filepath2,custom_objects={'cross_entropy_loss':cross_entropy_loss,'dice_coef':dice_coef,'custom_metrics':custom_metrics})

# %%
len(color_list)
# Out:
# 38

# %%
import matplotlib
cmap = matplotlib.colors.ListedColormap(color_list)
cmap1=matplotlib.colors.ListedColormap(color_list)
def plot(image,mask):
    plt.figure(figsize=(14,14))
    # plt.subplot(141)
    # plt.imshow(np.squeeze(prediction)+1,cmap=cmap,vmin=1, vmax=len(color_list))
    # print('here it is')
    # print(np.squeeze(prediction).shape)
    plt.subplot(142)
    plt.imshow(image)
    plt.subplot(143)
    plt.imshow(np.squeeze(mask[:,:,1])+1,cmap=cmap1,vmin=1, vmax=len(color_list))
    print('here it is')
    print(np.squeeze(mask[:,:,2]).shape)
    # plt.subplot(144)
    # plt.imshow(numpy,cmap='gray')
    # print(prediction)

# %%
# import matplotlib
# def plot(image,numpy,prediction):
#     plt.figure(figsize=(14,14))
#     plt.subplot(131)
#     plt.imshow(np.squeeze(prediction),cmap=plt.get_cmap('gray'))
#     plt.subplot(132)
#     plt.imshow(image)
#     plt.subplot(133)
#     plt.imshow(numpy,cmap='gray')

# %%
import cv2 as cv
def prediction(path):
    image = cv.imread(path,cv.IMREAD_COLOR)
    x = cv.resize(image,(640,480),interpolation=cv.INTER_NEAREST)
    x = x/255.0
    x=np.expand_dims(x,0)
    # y = dahal.predict(x)
    # print(y.shape)
    # numpy = np.zeros((y.shape[1],y.shape[2],y.shape[3]))
    # print(numpy.shape)
    # numpy[:,:,:] = y 
    # prediction= numpy.argmax(axis=-1)
    # print(prediction.shape)
    # numpy= tf.one_hot(prediction,38)
    mask = cv.imread(path1,cv.IMREAD_COLOR)
    mask = cv.resize(mask,(640,480),interpolation=cv.INTER_NEAREST)
    plot(image,mask)
    
path = '/content/drive/MyDrive/depth/image/image7963 (1).jpg'
path1='/content/drive/MyDrive/depth/mask/mask7963 (1).png'

prediction1=prediction(path)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-24-3b1cd188718b> in <module>()
#      20 path1='/content/drive/MyDrive/depth/mask/mask7963 (1).png'
#      21
# ---> 22 prediction1=prediction(path)
#      23
#
# <ipython-input-24-3b1cd188718b> in prediction(path)
#      14     # numpy= tf.one_hot(prediction,38)
#      15     mask = cv.imread(path1,cv.IMREAD_COLOR)
# ---> 16     mask = cv.resize(mask,(640,480),interpolation=cv.INTER_NEAREST)
#      17     plot(image,mask)
#      18
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# 5457,*1729,2831*
# 2831: bathtub good result

# %%
for i in range(prediction1.shape[2]):
    # for j in range(prediction1.shape[1]):
    #     # if prediction1[i,j]>2:
    (prediction1.shape)
    print(prediction1[])

# %%
import matplotlib
# %matplotlib inline
cmap = matplotlib.colors.ListedColormap(color_list)
def p1(path):
    image = cv.imread(path,cv.IMREAD_COLOR)
    x = cv.resize(image,(640,480),interpolation=cv.INTER_NEAREST)
    x = x/255.0
    x=np.expand_dims(x,0)
    print(x.shape)
    return x
def plot2(prediction):
    plt.figure(figsize=(14,14))
    plt.subplot(131)
    plt.imshow(np.squeeze(prediction)+1,cmap=cmap,vmin=1, vmax=len(color_list)) 
import tensorflow as tf

# %%
layer_names=[layer.name for layer in dahal.layers]
layer_names

# %%
layer_names
# Out:
# ['input_6',
#  'conv2d_180',
#  'spatial_dropout2d_127',
#  'batch_normalization_176',
#  'leaky_re_lu_176',
#  'conv2d_181',
#  'spatial_dropout2d_128',
#  'batch_normalization_177',
#  'leaky_re_lu_177',
#  'max_pooling2d_25',
#  'conv2d_182',
#  'spatial_dropout2d_129',
#  'batch_normalization_178',
#  'leaky_re_lu_178',
#  'conv2d_183',
#  'spatial_dropout2d_130',
#  'batch_normalization_179',
#  'leaky_re_lu_179',
#  'max_pooling2d_26',
#  'conv2d_187',
#  'spatial_dropout2d_133',
#  'batch_normalization_183',
#  'leaky_re_lu_183',
#  'conv2d_188',
#  'spatial_dropout2d_134',
#  'batch_normalization_184',
#  'leaky_re_lu_184',
#  'max_pooling2d_27',
#  'conv2d_192',
#  'spatial_dropout2d_137',
#  'batch_normalization_188',
#  'leaky_re_lu_188',
#  'conv2d_193',
#  'spatial_dropout2d_138',
#  'batch_normalization_189',
#  'leaky_re_lu_189',
#  'max_pooling2d_28',
#  'conv2d_197',
#  'spatial_dropout2d_141',
#  'batch_normalization_193',
#  'leaky_re_lu_193',
#  'conv2d_198',
#  'spatial_dropout2d_142',
#  'batch_normalization_194',
#  'leaky_re_lu_194',
#  'conv2d_199',
#  'spatial_dropout2d_143',
#  'max_pooling2d_29',
#  'batch_normalization_195',
#  'conv2d_202',
#  'leaky_re_lu_195',
#  'spatial_dropout2d_145',
#  'conv2d_200',
#  'batch_normalization_198',
#  'spatial_dropout2d_144',
#  'leaky_re_lu_198',
#  'batch_normalization_196',
#  'conv2d_203',
#  'leaky_re_lu_196',
#  'batch_normalization_199',
#  'conv2d_201',
#  'leaky_re_lu_199',
#  'batch_normalization_197',
#  'conv2d_194',
#  'up_sampling2d_21',
#  'leaky_re_lu_197',
#  'spatial_dropout2d_139',
#  'multiply_17',
#  'batch_normalization_190',
#  'conv2d_204',
#  'leaky_re_lu_190',
#  'spatial_dropout2d_146',
#  'conv2d_195',
#  'batch_normalization_200',
#  'spatial_dropout2d_140',
#  'leaky_re_lu_200',
#  'batch_normalization_191',
#  'conv2d_205',
#  'leaky_re_lu_191',
#  'batch_normalization_201',
#  'conv2d_196',
#  'leaky_re_lu_201',
#  'batch_normalization_192',
#  'conv2d_189',
#  'up_sampling2d_22',
#  'leaky_re_lu_192',
#  'spatial_dropout2d_135',
#  'multiply_18',
#  'batch_normalization_185',
#  'conv2d_206',
#  'leaky_re_lu_185',
#  'spatial_dropout2d_147',
#  'conv2d_190',
#  'batch_normalization_202',
#  'spatial_dropout2d_136',
#  'leaky_re_lu_202',
#  'batch_normalization_186',
#  'conv2d_207',
#  'leaky_re_lu_186',
#  'batch_normalization_203',
#  'conv2d_191',
#  'leaky_re_lu_203',
#  'batch_normalization_187',
#  'conv2d_184',
#  'up_sampling2d_23',
#  'leaky_re_lu_187',
#  'spatial_dropout2d_131',
#  'multiply_19',
#  'batch_normalization_180',
#  'conv2d_208',
#  'leaky_re_lu_180',
#  'spatial_dropout2d_148',
#  'conv2d_185',
#  'batch_normalization_204',
#  'spatial_dropout2d_132',
#  'leaky_re_lu_204',
#  'batch_normalization_181',
#  'conv2d_209',
#  'leaky_re_lu_181',
#  'batch_normalization_205',
#  'conv2d_186',
#  'leaky_re_lu_205',
#  'batch_normalization_182',
#  'up_sampling2d_24',
#  'leaky_re_lu_182',
#  'multiply_20',
#  'conv2d_210',
#  'spatial_dropout2d_149',
#  'batch_normalization_206',
#  'leaky_re_lu_206',
#  'conv2d_211',
#  'batch_normalization_207',
#  'leaky_re_lu_207',
#  'up_sampling2d_25',
#  'conv2d_212']

# %%
def layer_plot(path,layer_name):
  # dahal=tf.keras.models.load_model('/content/drive/MyDrive/training-daily/july21/kale6',custom_objects={'cross_entropy_loss':cross_entropy_loss,'custom_metrics':custom_metrics})
  layer_names=[]
  layer_names=[layer.name for layer in dahal.layers] ### here you can print this output to check the lists of layer names
  features_layer1 = dahal
  p11=features_layer1.predict(p1(path))
  numpy = np.zeros((p11.shape[1],p11.shape[2],p11.shape[3]))
  print(numpy.shape)
  numpy[:,:,:] = p11 
  prediction= numpy.argmax(axis=-1)
  plot2(prediction)
path='/content/drive/MyDrive/depth/image/image1.jpg'
# dahal=tf.keras.models.load_model('/content/drive/MyDrive/training-daily/july21/kale6',custom_objects={'cross_entropy_loss':cross_entropy_loss,'custom_metrics':custom_metrics})
layer_names=[]
layer_names=[layer.name for layer in dahal.layers]
layer=['conv2d_180','conv2d_182','conv2d_187','conv2d_191','conv2d_208','conv2d_192','conv2d_210','conv2d_212']
layer_plot(path,'conv2d_212')
# for i in layer:
#   layer_plot(path,i)
# Out:
# (1, 480, 640, 3)
# (480, 640, 38)

# %%
layer_names
# Out:
# ['input_6',
#  'conv2d_180',
#  'spatial_dropout2d_127',
#  'batch_normalization_176',
#  'leaky_re_lu_176',
#  'conv2d_181',
#  'spatial_dropout2d_128',
#  'batch_normalization_177',
#  'leaky_re_lu_177',
#  'max_pooling2d_25',
#  'conv2d_182',
#  'spatial_dropout2d_129',
#  'batch_normalization_178',
#  'leaky_re_lu_178',
#  'conv2d_183',
#  'spatial_dropout2d_130',
#  'batch_normalization_179',
#  'leaky_re_lu_179',
#  'max_pooling2d_26',
#  'conv2d_187',
#  'spatial_dropout2d_133',
#  'batch_normalization_183',
#  'leaky_re_lu_183',
#  'conv2d_188',
#  'spatial_dropout2d_134',
#  'batch_normalization_184',
#  'leaky_re_lu_184',
#  'max_pooling2d_27',
#  'conv2d_192',
#  'spatial_dropout2d_137',
#  'batch_normalization_188',
#  'leaky_re_lu_188',
#  'conv2d_193',
#  'spatial_dropout2d_138',
#  'batch_normalization_189',
#  'leaky_re_lu_189',
#  'max_pooling2d_28',
#  'conv2d_197',
#  'spatial_dropout2d_141',
#  'batch_normalization_193',
#  'leaky_re_lu_193',
#  'conv2d_198',
#  'spatial_dropout2d_142',
#  'batch_normalization_194',
#  'leaky_re_lu_194',
#  'conv2d_199',
#  'spatial_dropout2d_143',
#  'max_pooling2d_29',
#  'batch_normalization_195',
#  'conv2d_202',
#  'leaky_re_lu_195',
#  'spatial_dropout2d_145',
#  'conv2d_200',
#  'batch_normalization_198',
#  'spatial_dropout2d_144',
#  'leaky_re_lu_198',
#  'batch_normalization_196',
#  'conv2d_203',
#  'leaky_re_lu_196',
#  'batch_normalization_199',
#  'conv2d_201',
#  'leaky_re_lu_199',
#  'batch_normalization_197',
#  'conv2d_194',
#  'up_sampling2d_21',
#  'leaky_re_lu_197',
#  'spatial_dropout2d_139',
#  'multiply_17',
#  'batch_normalization_190',
#  'conv2d_204',
#  'leaky_re_lu_190',
#  'spatial_dropout2d_146',
#  'conv2d_195',
#  'batch_normalization_200',
#  'spatial_dropout2d_140',
#  'leaky_re_lu_200',
#  'batch_normalization_191',
#  'conv2d_205',
#  'leaky_re_lu_191',
#  'batch_normalization_201',
#  'conv2d_196',
#  'leaky_re_lu_201',
#  'batch_normalization_192',
#  'conv2d_189',
#  'up_sampling2d_22',
#  'leaky_re_lu_192',
#  'spatial_dropout2d_135',
#  'multiply_18',
#  'batch_normalization_185',
#  'conv2d_206',
#  'leaky_re_lu_185',
#  'spatial_dropout2d_147',
#  'conv2d_190',
#  'batch_normalization_202',
#  'spatial_dropout2d_136',
#  'leaky_re_lu_202',
#  'batch_normalization_186',
#  'conv2d_207',
#  'leaky_re_lu_186',
#  'batch_normalization_203',
#  'conv2d_191',
#  'leaky_re_lu_203',
#  'batch_normalization_187',
#  'conv2d_184',
#  'up_sampling2d_23',
#  'leaky_re_lu_187',
#  'spatial_dropout2d_131',
#  'multiply_19',
#  'batch_normalization_180',
#  'conv2d_208',
#  'leaky_re_lu_180',
#  'spatial_dropout2d_148',
#  'conv2d_185',
#  'batch_normalization_204',
#  'spatial_dropout2d_132',
#  'leaky_re_lu_204',
#  'batch_normalization_181',
#  'conv2d_209',
#  'leaky_re_lu_181',
#  'batch_normalization_205',
#  'conv2d_186',
#  'leaky_re_lu_205',
#  'batch_normalization_182',
#  'up_sampling2d_24',
#  'leaky_re_lu_182',
#  'multiply_20',
#  'conv2d_210',
#  'spatial_dropout2d_149',
#  'batch_normalization_206',
#  'leaky_re_lu_206',
#  'conv2d_211',
#  'batch_normalization_207',
#  'leaky_re_lu_207',
#  'up_sampling2d_25',
#  'conv2d_212']
